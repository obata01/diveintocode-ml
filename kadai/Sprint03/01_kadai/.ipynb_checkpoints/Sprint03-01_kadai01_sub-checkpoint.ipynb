# %% [markdown]
# # Sprint 機械学習スクラッチ 線形回帰

# %% [markdown]
# ## 1.このSprintについて
#
# ### Sprintの目的
# - スクラッチを通して線形回帰を理解する
# - オブジェクト指向を意識した実装に慣れる
# - 数式をコードに落とし込めるようにする
#
# ### どのように学ぶか
# - スクラッチで線形回帰を実装した後、学習と検証を行なっていきます。

# %% [markdown]
# ## 2.線形回帰スクラッチ
#
# 線形回帰のクラスをスクラッチで作成していきます。NumPyなど最低限のライブラリのみを使いアルゴリズムを実装していきます。
#
# 以下に雛形を用意してあります。このScratchLinearRegressionクラスにコードを書き加えていってください。
#
# **雛形**
#
# `````
# class ScratchLogisticRegression():
#     """
#     ロジスティック回帰のスクラッチ実装
#
#     Parameters
#     ----------
#     num_iter : int
#       イテレーション数
#     lr : float
#       学習率
#     no_bias : bool
#       バイアス項を入れない場合はTrue
#     verbose : bool
#       学習過程を出力する場合はTrue
#
#     Attributes
#     ----------
#     self.coef_ : 次の形のndarray, shape (n_features,)
#       パラメータ
#     self.loss : 次の形のndarray, shape (self.iter,)
#       訓練データに対する損失の記録
#     self.val_loss : 次の形のndarray, shape (self.iter,)
#       検証データに対する損失の記録
#
#     """
#     def __init__(self, num_iter, lr, bias, verbose):
#         # ハイパーパラメータを属性として記録
#         self.iter = num_iter
#         self.lr = lr
#         self.bias = bias
#         self.verbose = verbose
#         # 損失を記録する配列を用意
#         self.loss = np.zeros(self.iter)
#         self.val_loss = np.zeros(self.iter)
#     def fit(self, X, y, X_val=None, y_val=None):
#         """
#         ロジスティック回帰を学習する。検証データが入力された場合はそれに対する損失と精度もイテレーションごとに計算する。
#
#         Parameters
#         ----------
#         X : 次の形のndarray, shape (n_samples, n_features)
#             訓練データの特徴量
#         y : 次の形のndarray, shape (n_samples, )
#             訓練データの正解値
#         X_val : 次の形のndarray, shape (n_samples, n_features)
#             検証データの特徴量
#         y_val : 次の形のndarray, shape (n_samples, )
#             検証データの正解値
#         """
#         if self.verbose:
#             #verboseをTrueにした際は学習過程を出力
#             print()
#         pass
#
#     def predict(self, X):
#         """
#         ロジスティック回帰を使いラベルを推定する。
#
#         Parameters
#         ----------
#         X : 次の形のndarray, shape (n_samples, n_features)
#             サンプル
#
#         Returns
#         -------
#             次の形のndarray, shape (n_samples, 1)
#             ロジスティック回帰による推定結果
#         """
#         pass
#         return
#     def predict_proba(self, X):
#         """
#         ロジスティック回帰を使い確率を推定する。
#
#         Parameters
#         ----------
#         X : 次の形のndarray, shape (n_samples, n_features)
#             サンプル
#
#         Returns
#         -------
#             次の形のndarray, shape (n_samples, 1)
#             ロジスティック回帰による推定結果
#         """
#         pass
#         return
#
# `````

# %% [markdown]
# ## 【まとめ】最終的なコード
# 下記が最終的にFixしたコードは下記になり、全問題で共通になります。

# %%
class ScratchLinearRegression():
    """
    線形回帰のスクラッチ実装

    Parameters
    ----------
    num_iter : int
      イテレーション数
    lr : float
      学習率
    no_bias : bool
      バイアス項を入れない場合はTrue
    verbose : bool
      学習過程を出力する場合はTrue

    Attributes
    ----------
    self.coef_ : 次の形のndarray, shape (n_features,)
      パラメータ
    self.loss : 次の形のndarray, shape (self.iter,)
      訓練データに対する損失の記録
    self.val_loss : 次の形のndarray, shape (self.iter,)
      検証データに対する損失の記録

    """
    def __init__(self, num_iter, lr, no_bias, verbose, verbose_filter=1, q=0):
        # ハイパーパラメータを属性として記録
        self.iter = num_iter
        self.lr = lr
        self.no_bias = no_bias
        self.verbose = verbose
        self.verbose_filter = verbose_filter

        # 損失を記録する配列を用意
        self.loss = np.zeros(self.iter)
        self.val_loss = np.zeros(self.iter)

        # 問題番号別の制御用
        self.q = q

    def fit(self, X, y, X_val=None, y_val=None):
        """
        線形回帰を学習する。検証データが入力された場合はそれに対する損失と精度もイテレーションごとに計算する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            訓練データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            訓練データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証データの正解値
        """
        # 引数チェック
        assert len(X) == len(y), "[ERROR] The number of rows of X and y are different."
        if np.all(X_val != None) or np.all(y_val != None):
            assert len(X_val) == len(y_val), "[ERROR] The number of rows of X_val and y_val are different."

        # インスタンス変数の設定
        X, y, X_val, y_val = self._set_variables(X, y, X_val, y_val)

        # メイン処理
        for i in range(self.iter):

            # ループ回数をインスタンス変数へ代入
            self.count = i

            # 推定値(y_hypo)計算
            self.y_hypo = self._linear_hypothesis(X)

            # 最急降下法実行して値を更新
            self.w, self.error = self._gradient_descent(X, y, self.y_hypo, self.n_samples)

            # 損失関数
            self.loss[i] = self._loss_func(self.error, self.n_samples)


            # 検証データの損失関数
            if np.all(X_val != None) and np.all(y_val != None):
                # 推定値(y_hypo)計算
                self.y_hypo_val = self._linear_hypothesis(X_val)

                # 最急降下法実行して値を更新
                _, self.error_val = self._gradient_descent(X_val, y_val, self.y_hypo_val, self.n_samples_val)

                # 損失関数
                self.val_loss[i] = self._loss_func(self.error_val, self.n_samples_val)

            if self.verbose and self.count % self.verbose_filter == 0:
                #verboseをTrueにした際は学習過程を出力
                print('[INFO] loop count =', self.count)
                print('[INFO] update_w\n', self.w)
            pass
        pass





    # インスタンス変数の設定
    def _set_variables(self, X, y, X_val, y_val):
        """
        説明
        """
        # ループカウント用
        self.count = 0

        # トレーニングデータの形状
        self.n_samples = X.shape[0]
        self.n_features = X.shape[1]

        # テストデータの形状
        if np.all(X_val != None):
            self.n_samples_val = X_val.shape[0]
            self.n_features_val = X_val.shape[1]

        # no_bias=Falseのとき特徴量カラムを1列追加
        if not self.no_bias:
            print('[INFO] no_bias=False')

            # トレーニングデータの処理
            self.n_features += 1
            b = np.ones([self.n_samples, 1])
            X = np.concatenate([b, X], axis=1)

            # テストデータの処理
            if np.all(X_val != None):
                self.n_features_val += 1
                b = np.ones([self.n_samples_val, 1])
                X_val = np.concatenate([b, X_val], axis=1)

        # パラメータ初期値設定
#         self.w = np.random.randn(self.n_features) + 0.1
        self.w = np.full(self.n_features,2)  # テスト用に固定値代
        if not self.no_bias:
            self.w[0] = 30

        # 変数初期化
        self.y_hypo = 0
        self.error = 0
        self.y_hypo_val = 0
        self.error_val = 0

        return X, y, X_val, y_val




    # 推定値計算の処理
    def _linear_hypothesis(self, X):
        """
        線形の仮定関数を計算する

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
        訓練データ

        Returns
        -------
        次の形のndarray, shape (n_samples, 1)
        線形の仮定関数による推定結果

        """
        
#         print(self.w.shape)
#         print(self.w.T)
#         print(X)
#         print(X.shape)

        y_hypo = X @ self.w.T

        # 課題提出用
        if self.q == 1 and self.count % self.verbose_filter == 0:
            print('Loop count :', self.count)
            print('仮定関数計算結果 :', y_hypo)

        return y_hypo




    # 最急降下法の処理
    def _gradient_descent(self, X, y, y_hypo, n_samples):
        """
        説明を記述
        """
        # 誤差の計算
        error = y_hypo - y
        error = error[:, np.newaxis]

        update_w = self.w - (self.lr * np.sum(error * X, axis=0) / n_samples)

        # 課題提出用
        if self.q == 2 and self.count % self.verbose_filter == 0:
            print('Loop count :', self.count)
            print('誤差 :\n', error)
            print('更新値 :', update_w)

        return update_w, error




    def predict(self, X):
        """
        線形回帰を使い推定する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            サンプル

        Returns
        -------
            次の形のndarray, shape (n_samples, 1)
            線形回帰による推定結果
        """
        if not self.no_bias:
            b = np.ones([X.shape[0], 1])
            X = np.concatenate([b, X], axis=1)
        
        # 予測値を計算
        y_pred = self._linear_hypothesis(X)
        
        return y_pred



    # 損失関数
    def _loss_func(self, error, n_samples):
        """
        損失関数
        """
        loss = np.sum(error**2) / (2*n_samples)
        
        return loss

# %% [markdown]
# ## 【問題1】仮定関数
# 以下の数式で表される線形回帰の仮定関数を実装してください。メソッドの雛形を用意してあります。
#
# $x$ : 特徴量ベクトル
#
#
# $\theta$ : パラメータベクトル
#
#
# $n$ : 特徴量の数
#
#
# $x_j$ : j番目の特徴量
#
#
# $\theta_j$ : j番目のパラメータ（重み）
#
#
# 特徴量の数$n$は任意の値に対応できる実装にしてください。
#
#
# なお、ベクトル形式で表すと以下のようになります。
#
# **雛形**
#
# クラスの外から呼び出すことがないメソッドのため、Pythonの慣例としてアンダースコアを先頭にひとつつけています。

# %%
# ライブラリインポート
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %%
# テストデータ
x = np.array([[1, 5],
                [2, 8],
                [3, 9]])
y = np.arange(6, 9)

# %%
# no_bias=False
slr = ScratchLinearRegression(num_iter=1, lr=0.01, no_bias=False, verbose=False, verbose_filter=1, q=1)
slr.fit(x, y)
# Out:
# [INFO] no_bias=False
# Loop count : 0
# 仮定関数計算結果 : [14. 22. 26.]

# %%
# no_bias=True
slr = ScratchLinearRegression(num_iter=1, lr=0.01, no_bias=True, verbose=False, verbose_filter=1, q=1)
slr.fit(x, y)
# Out:
# Loop count : 0
# 仮定関数計算結果 : [12 20 24]

# %% [markdown]
# ## 【問題2】最急降下法
# 最急降下法により学習させる実装を行なってください。以下の式で表されるパラメータの更新式のメソッド_gradient_descentを追加し、fit
# メソッドから呼び出すようにしてください。
#
# $\alpha$ : 学習率
#
#
# $i$ : サンプルのインデックス
#
#
# $j$ : 特徴量のインデックス
#
#
# 雛形
#
#
# ScratchLinearRegressionクラスへ以下のメソッドを追加してください。コメントアウト部分の説明も記述してください。

# %%
# no_bias=False
slr = ScratchLinearRegression(num_iter=1001, lr=0.01, no_bias=False, verbose=False, verbose_filter=500, q=2)
slr.fit(x, y)
# Out:
# [INFO] no_bias=False
# Loop count : 0
# 誤差 :
#  [[ 8.]
#  [15.]
#  [18.]]
# 更新値 : [1.86333333 1.69333333 0.92666667]
# Loop count : 500
# 誤差 :
#  [[-0.71016546]
#  [ 0.1931363 ]
#  [ 0.21689637]]
# 更新値 : [2.50799154 0.5828999  0.43994974]
# Loop count : 1000
# 誤差 :
#  [[-0.4385435 ]
#  [ 0.26927145]
#  [ 0.00321982]]
# 更新値 : [2.88032847 0.24664955 0.48696518]

# %%
# no_bias=False
slr = ScratchLinearRegression(num_iter=1001, lr=0.01, no_bias=True, verbose=False, verbose_filter=500, q=2)
slr.fit(x, y)
# Out:
# Loop count : 0
# 誤差 :
#  [[ 6]
#  [13]
#  [16]]
# 更新値 : [1.73333333 1.07333333]
# Loop count : 500
# 誤差 :
#  [[-1.40134304]
#  [ 0.39993668]
#  [ 0.40383917]]
# 更新値 : [0.10318038 0.89926418]
# Loop count : 1000
# 誤差 :
#  [[-1.09623937]
#  [ 0.59417614]
#  [ 0.07124651]]
# 更新値 : [-0.6306217   1.10696113]

# %% [markdown]
# 雛形として用意されたメソッドや関数以外でも必要があれば各自作成して完成させてください。雛形を外れても問題ありません。

# %% [markdown]
# ## 【問題3】推定
# 推定する仕組みを実装してください。ScratchLinearRegressionクラスの雛形に含まれるpredictメソッドに書き加えてください。
#
#
# 仮定関数 $h_\theta(x)$ の出力が推定結果です。

# %%
# テストデータ
x = np.array([[1, 5],
                [2, 8],
                [3, 9]])
y = np.arange(6, 9)

# %% [markdown]
# 上記テストデータの解をは下記になるため、スクラッチプログラムの実行結果も近似する想定。
# - θ_0 = 5
# - θ_1 = 1
# - θ_2 = 0

# %%
# 解を求める計算式
x = np.array([[1, 5],
                [2, 8],
                [3, 9]])
b = np.ones(3)[:,np.newaxis]
x = np.concatenate([b, x], axis=1)
y = np.arange(6, 9)
ab = np.linalg.pinv(x[:x.shape[1],:]) @ y[:x.shape[1]][:, np.newaxis]
print('解：{:.3f}, {:.3f}, {:.3f}'.format(ab[0,0], ab[1,0], ab[2,0]))
# Out:
# 解：5.000, 1.000, 0.000

# %%
# 標準化（テスト用）
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
x_std = scaler.transform(x)
x_std
# Out:
# array([[ 0.        , -1.22474487, -1.37281295],
#        [ 0.        ,  0.        ,  0.39223227],
#        [ 0.        ,  1.22474487,  0.98058068]])

# %%
# no_bias=True
slr = ScratchLinearRegression(num_iter=10000, lr=0.01, no_bias=True, verbose=True)
slr.fit(x, y)
# Out:
# [INFO] loop count = 0
# [INFO] update_w
#  [1.86333333 1.69333333 0.92666667]
# [INFO] loop count = 1
# [INFO] update_w
#  [1.81287778 1.57544444 0.52064444]
# [INFO] loop count = 2
# [INFO] update_w
#  [1.79505952 1.5290297  0.36726378]
# [INFO] loop count = 3
# [INFO] update_w
#  [1.78959565 1.50967826 0.30953185]
# [INFO] loop count = 4
# [INFO] update_w
#  [1.78880713 1.50057626 0.2880116 ]
# [INFO] loop count = 5
# [INFO] update_w
#  [1.78978668 1.49535804 0.2802003 ]
# [INFO] loop count = 6
# [INFO] update_w
#  [1.79143363 1.49161355 0.27757849]
# [INFO] loop count = 7
# [INFO] update_w
#  [1.79333127 1.48843035 0.27692071]
# [INFO] loop count = 8
# [INFO] update_w
#  [1.79532183 1.48546299 0.27700583]
# [INFO] loop count = 9
# [INFO] update_w
#  [1.79734559 1.48258069 0.27737151]
# [INFO] loop count = 10
# [INFO] update_w
#  [1.79937994 1.4797339  0.27784274]
# [INFO] loop count = 11
# [INFO] update_w
#  [1.80141633 1.47690388 0.27835323]
# [INFO] loop count = 12
# [INFO] update_w
#  [1.80345152 1.47408352 0.27887791]
# [INFO] loop count = 13
# [INFO] update_w
#  [1.80548429 1.47127013 0.27940729]
# [INFO] loop count = 14
# [INFO] update_w
#  [1.80751417 1.46846267 0.27993776]
# [INFO] loop count = 15
# [INFO] update_w
#  [1.80954101 1.46566076 0.28046796]
# [INFO] loop count = 16
# [INFO] update_w
#  [1.81156474 1.46286423 0.28099739]
# [INFO] loop count = 17
# [INFO] update_w
#  [1.81358533 1.46007302 0.28152584]
# [INFO] loop count = 18
# [INFO] update_w
#  [1.81560279 1.4572871  0.28205326]
# [INFO] loop count = 19
# [INFO] update_w
#  [1.81761711 1.45450646 0.2825796 ]
# [INFO] loop count = 20
# [INFO] update_w
#  [1.81962831 1.45173108 0.28310487]
# [INFO] loop count = 21
# [INFO] update_w
#  [1.82163638 1.44896095 0.28362906]
# [INFO] loop count = 22
# [INFO] update_w
#  [1.82364133 1.44619606 0.28415217]
# [INFO] loop count = 23
# [INFO] update_w
#  [1.82564317 1.4434364  0.28467421]
# [INFO] loop count = 24
# [INFO] update_w
#  [1.8276419  1.44068197 0.28519517]
# [INFO] loop count = 25
# [INFO] update_w
#  [1.82963753 1.43793275 0.28571505]
# [INFO] loop count = 26
# [INFO] update_w
#  [1.83163006 1.43518873 0.28623386]
# [INFO] loop count = 27
# [INFO] update_w
#  [1.8336195  1.4324499  0.28675161]
# [INFO] loop count = 28
# [INFO] update_w
#  [1.83560586 1.42971626 0.28726828]
# [INFO] loop count = 29
# [INFO] update_w
#  [1.83758914 1.42698779 0.28778389]
# [INFO] loop count = 30
# [INFO] update_w
#  [1.83956934 1.42426449 0.28829844]
# [INFO] loop count = 31
# [INFO] update_w
#  [1.84154647 1.42154634 0.28881192]
# [INFO] loop count = 32
# [INFO] update_w
#  [1.84352054 1.41883334 0.28932434]
# [INFO] loop count = 33
# [INFO] update_w
#  [1.84549154 1.41612548 0.28983571]
# [INFO] loop count = 34
# [INFO] update_w
#  [1.8474595  1.41342275 0.29034602]
# [INFO] loop count = 35
# [INFO] update_w
#  [1.84942441 1.41072513 0.29085527]
# [INFO] loop count = 36
# [INFO] update_w
#  [1.85138628 1.40803263 0.29136347]
# [INFO] loop count = 37
# [INFO] update_w
#  [1.85334511 1.40534522 0.29187062]
# [INFO] loop count = 38
# [INFO] update_w
#  [1.85530091 1.40266291 0.29237673]
# [INFO] loop count = 39
# [INFO] update_w
#  [1.85725368 1.39998568 0.29288178]
# [INFO] loop count = 40
# [INFO] update_w
#  [1.85920343 1.39731352 0.29338579]
# [INFO] loop count = 41
# [INFO] update_w
#  [1.86115017 1.39464643 0.29388876]
# [INFO] loop count = 42
# [INFO] update_w
#  [1.86309389 1.39198439 0.29439069]
# [INFO] loop count = 43
# [INFO] update_w
#  [1.86503462 1.3893274  0.29489158]
# [INFO] loop count = 44
# [INFO] update_w
#  [1.86697234 1.38667544 0.29539143]
# [INFO] loop count = 45
# [INFO] update_w
#  [1.86890707 1.38402851 0.29589024]
# [INFO] loop count = 46
# [INFO] update_w
#  [1.87083881 1.3813866  0.29638802]
# [INFO] loop count = 47
# [INFO] update_w
#  [1.87276757 1.3787497  0.29688477]
# [INFO] loop count = 48
# [INFO] update_w
#  [1.87469335 1.3761178  0.2973805 ]
# [INFO] loop count = 49
# [INFO] update_w
#  [1.87661616 1.37349089 0.29787519]
# [INFO] loop count = 50
# [INFO] update_w
#  [1.878536   1.37086896 0.29836885]
# [INFO] loop count = 51
# [INFO] update_w
#  [1.88045288 1.36825201 0.2988615 ]
# [INFO] loop count = 52
# [INFO] update_w
#  [1.8823668  1.36564002 0.29935312]
# [INFO] loop count = 53
# [INFO] update_w
#  [1.88427777 1.36303298 0.29984372]
# [INFO] loop count = 54
# [INFO] update_w
#  [1.88618579 1.36043089 0.3003333 ]
# [INFO] loop count = 55
# [INFO] update_w
#  [1.88809087 1.35783374 0.30082186]
# [INFO] loop count = 56
# [INFO] update_w
#  [1.88999302 1.35524152 0.30130941]
# [INFO] loop count = 57
# [INFO] update_w
#  [1.89189224 1.35265421 0.30179595]
# [INFO] loop count = 58
# [INFO] update_w
#  [1.89378853 1.35007182 0.30228147]
# [INFO] loop count = 59
# [INFO] update_w
#  [1.8956819  1.34749433 0.30276599]
# [INFO] loop count = 60
# [INFO] update_w
#  [1.89757235 1.34492173 0.3032495 ]
# [INFO] loop count = 61
# [INFO] update_w
#  [1.8994599  1.34235402 0.303732  ]
# [INFO] loop count = 62
# [INFO] update_w
#  [1.90134454 1.33979118 0.3042135 ]
# [INFO] loop count = 63
# [INFO] update_w
#  [1.90322628 1.33723321 0.30469399]
# [INFO] loop count = 64
# [INFO] update_w
#  [1.90510513 1.33468009 0.30517349]
# [INFO] loop count = 65
# [INFO] update_w
#  [1.90698108 1.33213183 0.30565199]
# [INFO] loop count = 66
# [INFO] update_w
#  [1.90885416 1.3295884  0.30612949]
# [INFO] loop count = 67
# [INFO] update_w
#  [1.91072435 1.32704981 0.306606  ]
# [INFO] loop count = 68
# [INFO] update_w
#  [1.91259167 1.32451604 0.30708151]
# [INFO] loop count = 69
# [INFO] update_w
#  [1.91445612 1.32198708 0.30755603]
# [INFO] loop count = 70
# [INFO] update_w
#  [1.91631771 1.31946293 0.30802957]
# [INFO] loop count = 71
# [INFO] update_w
#  [1.91817644 1.31694357 0.30850211]
# [INFO] loop count = 72
# [INFO] update_w
#  [1.92003232 1.31442901 0.30897367]
# [INFO] loop count = 73
# [INFO] update_w
#  [1.92188535 1.31191922 0.30944425]
# [INFO] loop count = 74
# [INFO] update_w
#  [1.92373553 1.3094142  0.30991384]
# [INFO] loop count = 75
# [INFO] update_w
#  [1.92558288 1.30691395 0.31038245]
# [INFO] loop count = 76
# [INFO] update_w
#  [1.92742739 1.30441845 0.31085009]
# [INFO] loop count = 77
# [INFO] update_w
#  [1.92926907 1.30192769 0.31131674]
# [INFO] loop count = 78
# [INFO] update_w
#  [1.93110793 1.29944167 0.31178243]
# [INFO] loop count = 79
# [INFO] update_w
#  [1.93294398 1.29696038 0.31224714]
# [INFO] loop count = 80
# [INFO] update_w
#  [1.9347772  1.29448381 0.31271087]
# [INFO] loop count = 81
# [INFO] update_w
#  [1.93660763 1.29201195 0.31317364]
# [INFO] loop count = 82
# [INFO] update_w
#  [1.93843524 1.28954479 0.31363544]
# [INFO] loop count = 83
# [INFO] update_w
#  [1.94026006 1.28708232 0.31409627]
# [INFO] loop count = 84
# [INFO] update_w
#  [1.94208209 1.28462454 0.31455614]
# [INFO] loop count = 85
# [INFO] update_w
#  [1.94390133 1.28217144 0.31501505]
# [INFO] loop count = 86
# [INFO] update_w
#  [1.94571778 1.27972301 0.31547299]
# [INFO] loop count = 87
# [INFO] update_w
#  [1.94753146 1.27727923 0.31592998]
# [INFO] loop count = 88
# [INFO] update_w
#  [1.94934236 1.27484011 0.31638601]
# [INFO] loop count = 89
# [INFO] update_w
#  [1.95115049 1.27240563 0.31684108]
# [INFO] loop count = 90
# [INFO] update_w
#  [1.95295586 1.26997578 0.3172952 ]
# [INFO] loop count = 91
# [INFO] update_w
#  [1.95475847 1.26755056 0.31774836]
# [INFO] loop count = 92
# [INFO] update_w
#  [1.95655833 1.26512996 0.31820058]
# [INFO] loop count = 93
# [INFO] update_w
#  [1.95835544 1.26271397 0.31865185]
# [INFO] loop count = 94
# [INFO] update_w
#  [1.9601498  1.26030258 0.31910217]
# [INFO] loop count = 95
# [INFO] update_w
#  [1.96194143 1.25789579 0.31955154]
# [INFO] loop count = 96
# [INFO] update_w
#  [1.96373032 1.25549357 0.31999997]
# [INFO] loop count = 97
# [INFO] update_w
#  [1.96551648 1.25309594 0.32044746]
# [INFO] loop count = 98
# [INFO] update_w
#  [1.96729992 1.25070287 0.32089401]
# [INFO] loop count = 99
# [INFO] update_w
#  [1.96908063 1.24831437 0.32133962]
# [INFO] loop count = 100
# [INFO] update_w
#  [1.97085863 1.24593041 0.32178429]
# [INFO] loop count = 101
# [INFO] update_w
#  [1.97263392 1.243551   0.32222803]
# [INFO] loop count = 102
# [INFO] update_w
#  [1.97440651 1.24117612 0.32267083]
# [INFO] loop count = 103
# [INFO] update_w
#  [1.9761764  1.23880577 0.3231127 ]
# [INFO] loop count = 104
# [INFO] update_w
#  [1.97794358 1.23643994 0.32355364]
# [INFO] loop count = 105
# [INFO] update_w
#  [1.97970808 1.23407863 0.32399366]
# [INFO] loop count = 106
# [INFO] update_w
#  [1.98146989 1.23172181 0.32443275]
# [INFO] loop count = 107
# [INFO] update_w
#  [1.98322902 1.22936949 0.32487091]
# [INFO] loop count = 108
# [INFO] update_w
#  [1.98498548 1.22702165 0.32530815]
# [INFO] loop count = 109
# [INFO] update_w
#  [1.98673926 1.2246783  0.32574446]
# [INFO] loop count = 110
# [INFO] update_w
#  [1.98849037 1.22233941 0.32617986]
# [INFO] loop count = 111
# [INFO] update_w
#  [1.99023882 1.22000498 0.32661434]
# [INFO] loop count = 112
# [INFO] update_w
#  [1.99198462 1.21767501 0.3270479 ]
# [INFO] loop count = 113
# [INFO] update_w
#  [1.99372776 1.21534949 0.32748055]
# [INFO] loop count = 114
# [INFO] update_w
#  [1.99546825 1.2130284  0.32791228]
# [INFO] loop count = 115
# [INFO] update_w
#  [1.9972061  1.21071175 0.32834311]
# [INFO] loop count = 116
# [INFO] update_w
#  [1.99894131 1.20839951 0.32877302]
# [INFO] loop count = 117
# [INFO] update_w
#  [2.00067388 1.20609169 0.32920202]
# [INFO] loop count = 118
# [INFO] update_w
#  [2.00240383 1.20378828 0.32963012]
# [INFO] loop count = 119
# [INFO] update_w
#  [2.00413115 1.20148926 0.33005731]
# [INFO] loop count = 120
# [INFO] update_w
#  [2.00585585 1.19919464 0.3304836 ]
# [INFO] loop count = 121
# [INFO] update_w
#  [2.00757794 1.1969044  0.33090899]
# [INFO] loop count = 122
# [INFO] update_w
#  [2.00929741 1.19461853 0.33133348]
# [INFO] loop count = 123
# [INFO] update_w
#  [2.01101428 1.19233702 0.33175707]
# [INFO] loop count = 124
# [INFO] update_w
#  [2.01272854 1.19005988 0.33217976]
# [INFO] loop count = 125
# [INFO] update_w
#  [2.01444021 1.18778709 0.33260155]
# [INFO] loop count = 126
# [INFO] update_w
#  [2.01614928 1.18551864 0.33302246]
# [INFO] loop count = 127
# [INFO] update_w
#  [2.01785577 1.18325452 0.33344247]
# [INFO] loop count = 128
# [INFO] update_w
#  [2.01955968 1.18099473 0.33386159]
# [INFO] loop count = 129
# [INFO] update_w
#  [2.021261   1.17873927 0.33427982]
# [INFO] loop count = 130
# [INFO] update_w
#  [2.02295975 1.17648811 0.33469717]
# [INFO] loop count = 131
# [INFO] update_w
#  [2.02465593 1.17424125 0.33511363]
# [INFO] loop count = 132
# [INFO] update_w
#  [2.02634955 1.1719987  0.3355292 ]
# [INFO] loop count = 133
# [INFO] update_w
#  [2.02804061 1.16976043 0.3359439 ]
# [INFO] loop count = 134
# [INFO] update_w
#  [2.02972911 1.16752644 0.33635771]
# [INFO] loop count = 135
# [INFO] update_w
#  [2.03141505 1.16529672 0.33677064]
# [INFO] loop count = 136
# [INFO] update_w
#  [2.03309846 1.16307127 0.3371827 ]
# [INFO] loop count = 137
# [INFO] update_w
#  [2.03477931 1.16085008 0.33759388]
# [INFO] loop count = 138
# [INFO] update_w
#  [2.03645763 1.15863313 0.33800419]
# [INFO] loop count = 139
# [INFO] update_w
#  [2.03813342 1.15642043 0.33841362]
# [INFO] loop count = 140
# [INFO] update_w
#  [2.03980668 1.15421197 0.33882218]
# [INFO] loop count = 141
# [INFO] update_w
#  [2.04147741 1.15200772 0.33922987]
# [INFO] loop count = 142
# [INFO] update_w
#  [2.04314563 1.1498077  0.3396367 ]
# [INFO] loop count = 143
# [INFO] update_w
#  [2.04481133 1.14761189 0.34004266]
# [INFO] loop count = 144
# [INFO] update_w
#  [2.04647451 1.14542028 0.34044775]
# [INFO] loop count = 145
# [INFO] update_w
#  [2.0481352  1.14323287 0.34085198]
# [INFO] loop count = 146
# [INFO] update_w
#  [2.04979337 1.14104965 0.34125535]
# [INFO] loop count = 147
# [INFO] update_w
#  [2.05144905 1.13887061 0.34165786]
# [INFO] loop count = 148
# [INFO] update_w
#  [2.05310224 1.13669574 0.34205951]
# [INFO] loop count = 149
# [INFO] update_w
#  [2.05475294 1.13452504 0.3424603 ]
# [INFO] loop count = 150
# [INFO] update_w
#  [2.05640115 1.1323585  0.34286024]
# [INFO] loop count = 151
# [INFO] update_w
#  [2.05804689 1.13019611 0.34325933]
# [INFO] loop count = 152
# [INFO] update_w
#  [2.05969015 1.12803786 0.34365756]
# [INFO] loop count = 153
# [INFO] update_w
#  [2.06133093 1.12588375 0.34405494]
# [INFO] loop count = 154
# [INFO] update_w
#  [2.06296925 1.12373376 0.34445147]
# [INFO] loop count = 155
# [INFO] update_w
#  [2.06460511 1.1215879  0.34484716]
# [INFO] loop count = 156
# [INFO] update_w
#  [2.06623851 1.11944615 0.345242  ]
# [INFO] loop count = 157
# [INFO] update_w
#  [2.06786946 1.11730851 0.34563599]
# [INFO] loop count = 158
# [INFO] update_w
#  [2.06949795 1.11517496 0.34602914]
# [INFO] loop count = 159
# [INFO] update_w
#  [2.071124   1.11304551 0.34642145]
# [INFO] loop count = 160
# [INFO] update_w
#  [2.07274761 1.11092014 0.34681292]
# [INFO] loop count = 161
# [INFO] update_w
#  [2.07436879 1.10879885 0.34720355]
# [INFO] loop count = 162
# [INFO] update_w
#  [2.07598753 1.10668162 0.34759335]
# [INFO] loop count = 163
# [INFO] update_w
#  [2.07760384 1.10456846 0.3479823 ]
# [INFO] loop count = 164
# [INFO] update_w
#  [2.07921773 1.10245936 0.34837043]
# [INFO] loop count = 165
# [INFO] update_w
#  [2.0808292  1.1003543  0.34875772]
# [INFO] loop count = 166
# [INFO] update_w
#  [2.08243826 1.09825328 0.34914418]
# [INFO] loop count = 167
# [INFO] update_w
#  [2.0840449  1.09615629 0.34952982]
# [INFO] loop count = 168
# [INFO] update_w
#  [2.08564914 1.09406333 0.34991462]
# [INFO] loop count = 169
# [INFO] update_w
#  [2.08725098 1.09197438 0.3502986 ]
# [INFO] loop count = 170
# [INFO] update_w
#  [2.08885042 1.08988945 0.35068175]
# [INFO] loop count = 171
# [INFO] update_w
#  [2.09044746 1.08780852 0.35106408]
# [INFO] loop count = 172
# [INFO] update_w
#  [2.09204212 1.08573158 0.35144559]
# [INFO] loop count = 173
# [INFO] update_w
#  [2.09363439 1.08365864 0.35182628]
# [INFO] loop count = 174
# [INFO] update_w
#  [2.09522428 1.08158968 0.35220615]
# [INFO] loop count = 175
# [INFO] update_w
#  [2.09681179 1.07952469 0.3525852 ]
# [INFO] loop count = 176
# [INFO] update_w
#  [2.09839693 1.07746367 0.35296344]
# [INFO] loop count = 177
# [INFO] update_w
#  [2.0999797  1.07540661 0.35334086]
# [INFO] loop count = 178
# [INFO] update_w
#  [2.10156011 1.0733535  0.35371747]
# [INFO] loop count = 179
# [INFO] update_w
#  [2.10313816 1.07130434 0.35409327]
# [INFO] loop count = 180
# [INFO] update_w
#  [2.10471385 1.06925912 0.35446826]
# [INFO] loop count = 181
# [INFO] update_w
#  [2.10628719 1.06721783 0.35484244]
# [INFO] loop count = 182
# [INFO] update_w
#  [2.10785818 1.06518046 0.35521581]
# [INFO] loop count = 183
# [INFO] update_w
#  [2.10942683 1.06314701 0.35558838]
# [INFO] loop count = 184
# [INFO] update_w
#  [2.11099314 1.06111748 0.35596014]
# [INFO] loop count = 185
# [INFO] update_w
#  [2.11255712 1.05909184 0.3563311 ]
# [INFO] loop count = 186
# [INFO] update_w
#  [2.11411876 1.0570701  0.35670126]
# [INFO] loop count = 187
# [INFO] update_w
#  [2.11567808 1.05505226 0.35707062]
# [INFO] loop count = 188
# [INFO] update_w
#  [2.11723507 1.05303829 0.35743918]
# [INFO] loop count = 189
# [INFO] update_w
#  [2.11878975 1.0510282  0.35780695]
# [INFO] loop count = 190
# [INFO] update_w
#  [2.12034211 1.04902198 0.35817392]
# [INFO] loop count = 191
# [INFO] update_w
#  [2.12189217 1.04701962 0.35854009]
# [INFO] loop count = 192
# [INFO] update_w
#  [2.12343991 1.04502111 0.35890548]
# [INFO] loop count = 193
# [INFO] update_w
#  [2.12498536 1.04302645 0.35927007]
# [INFO] loop count = 194
# [INFO] update_w
#  [2.1265285  1.04103563 0.35963387]
# [INFO] loop count = 195
# [INFO] update_w
#  [2.12806935 1.03904864 0.35999689]
# [INFO] loop count = 196
# [INFO] update_w
#  [2.12960791 1.03706549 0.36035912]
# [INFO] loop count = 197
# [INFO] update_w
#  [2.13114419 1.03508615 0.36072056]
# [INFO] loop count = 198
# [INFO] update_w
#  [2.13267819 1.03311062 0.36108122]
# [INFO] loop count = 199
# [INFO] update_w
#  [2.1342099 1.0311389 0.3614411]
# [INFO] loop count = 200
# [INFO] update_w
#  [2.13573934 1.02917098 0.36180019]
# [INFO] loop count = 201
# [INFO] update_w
#  [2.13726652 1.02720685 0.36215851]
# [INFO] loop count = 202
# [INFO] update_w
#  [2.13879142 1.0252465  0.36251605]
# [INFO] loop count = 203
# [INFO] update_w
#  [2.14031407 1.02328994 0.36287281]
# [INFO] loop count = 204
# [INFO] update_w
#  [2.14183446 1.02133714 0.3632288 ]
# [INFO] loop count = 205
# [INFO] update_w
#  [2.14335259 1.01938811 0.36358401]
# [INFO] loop count = 206
# [INFO] update_w
#  [2.14486848 1.01744284 0.36393845]
# [INFO] loop count = 207
# [INFO] update_w
#  [2.14638212 1.01550132 0.36429212]
# [INFO] loop count = 208
# [INFO] update_w
#  [2.14789351 1.01356354 0.36464502]
# [INFO] loop count = 209
# [INFO] update_w
#  [2.14940267 1.01162951 0.36499715]
# [INFO] loop count = 210
# [INFO] update_w
#  [2.1509096  1.0096992  0.36534851]
# [INFO] loop count = 211
# [INFO] update_w
#  [2.15241429 1.00777261 0.36569911]
# [INFO] loop count = 212
# [INFO] update_w
#  [2.15391676 1.00584975 0.36604895]
# [INFO] loop count = 213
# [INFO] update_w
#  [2.15541701 1.00393059 0.36639802]
# [INFO] loop count = 214
# [INFO] update_w
#  [2.15691504 1.00201514 0.36674633]
# [INFO] loop count = 215
# [INFO] update_w
#  [2.15841086 1.00010339 0.36709389]
# [INFO] loop count = 216
# [INFO] update_w
#  [2.15990446 0.99819532 0.36744068]
# [INFO] loop count = 217
# [INFO] update_w
#  [2.16139586 0.99629094 0.36778672]
# [INFO] loop count = 218
# [INFO] update_w
#  [2.16288506 0.99439024 0.368132  ]
# [INFO] loop count = 219
# [INFO] update_w
#  [2.16437206 0.99249321 0.36847652]
# [INFO] loop count = 220
# [INFO] update_w
#  [2.16585686 0.99059984 0.3688203 ]
# [INFO] loop count = 221
# [INFO] update_w
#  [2.16733947 0.98871013 0.36916332]
# [INFO] loop count = 222
# [INFO] update_w
#  [2.1688199  0.98682407 0.36950559]
# [INFO] loop count = 223
# [INFO] update_w
#  [2.17029814 0.98494166 0.36984711]
# [INFO] loop count = 224
# [INFO] update_w
#  [2.17177421 0.98306288 0.37018789]
# [INFO] loop count = 225
# [INFO] update_w
#  [2.17324809 0.98118773 0.37052792]
# [INFO] loop count = 226
# [INFO] update_w
#  [2.17471981 0.97931621 0.3708672 ]
# [INFO] loop count = 227
# [INFO] update_w
#  [2.17618936 0.9774483  0.37120574]
# [INFO] loop count = 228
# [INFO] update_w
#  [2.17765675 0.97558401 0.37154354]
# [INFO] loop count = 229
# [INFO] update_w
#  [2.17912197 0.97372332 0.3718806 ]
# [INFO] loop count = 230
# [INFO] update_w
#  [2.18058504 0.97186623 0.37221692]
# [INFO] loop count = 231
# [INFO] update_w
#  [2.18204596 0.97001273 0.3725525 ]
# [INFO] loop count = 232
# [INFO] update_w
#  [2.18350473 0.96816282 0.37288734]
# [INFO] loop count = 233
# [INFO] update_w
#  [2.18496136 0.96631649 0.37322145]
# [INFO] loop count = 234
# [INFO] update_w
#  [2.18641584 0.96447373 0.37355482]
# [INFO] loop count = 235
# [INFO] update_w
#  [2.18786819 0.96263453 0.37388747]
# [INFO] loop count = 236
# [INFO] update_w
#  [2.1893184  0.96079889 0.37421938]
# [INFO] loop count = 237
# [INFO] update_w
#  [2.19076648 0.95896681 0.37455056]
# [INFO] loop count = 238
# [INFO] update_w
#  [2.19221244 0.95713827 0.37488101]
# [INFO] loop count = 239
# [INFO] update_w
#  [2.19365628 0.95531328 0.37521073]
# [INFO] loop count = 240
# [INFO] update_w
#  [2.19509799 0.95349181 0.37553973]
# [INFO] loop count = 241
# [INFO] update_w
#  [2.1965376  0.95167388 0.37586801]
# [INFO] loop count = 242
# [INFO] update_w
#  [2.19797509 0.94985946 0.37619556]
# [INFO] loop count = 243
# [INFO] update_w
#  [2.19941048 0.94804857 0.37652239]
# [INFO] loop count = 244
# [INFO] update_w
#  [2.20084376 0.94624117 0.3768485 ]
# [INFO] loop count = 245
# [INFO] update_w
#  [2.20227494 0.94443728 0.37717388]
# [INFO] loop count = 246
# [INFO] update_w
#  [2.20370403 0.94263689 0.37749856]
# [INFO] loop count = 247
# [INFO] update_w
#  [2.20513102 0.94083999 0.37782251]
# [INFO] loop count = 248
# [INFO] update_w
#  [2.20655593 0.93904657 0.37814575]
# [INFO] loop count = 249
# [INFO] update_w
#  [2.20797875 0.93725662 0.37846827]
# [INFO] loop count = 250
# [INFO] update_w
#  [2.20939949 0.93547015 0.37879008]
# [INFO] loop count = 251
# [INFO] update_w
#  [2.21081815 0.93368714 0.37911118]
# [INFO] loop count = 252
# [INFO] update_w
#  [2.21223474 0.93190758 0.37943157]
# [INFO] loop count = 253
# [INFO] update_w
#  [2.21364926 0.93013148 0.37975125]
# [INFO] loop count = 254
# [INFO] update_w
#  [2.21506171 0.92835883 0.38007023]
# [INFO] loop count = 255
# [INFO] update_w
#  [2.2164721  0.92658961 0.38038849]
# [INFO] loop count = 256
# [INFO] update_w
#  [2.21788043 0.92482383 0.38070605]
# [INFO] loop count = 257
# [INFO] update_w
#  [2.21928671 0.92306147 0.38102291]
# [INFO] loop count = 258
# [INFO] update_w
#  [2.22069093 0.92130254 0.38133907]
# [INFO] loop count = 259
# [INFO] update_w
#  [2.22209311 0.91954702 0.38165452]
# [INFO] loop count = 260
# [INFO] update_w
#  [2.22349324 0.9177949  0.38196928]
# [INFO] loop count = 261
# [INFO] update_w
#  [2.22489133 0.91604619 0.38228333]
# [INFO] loop count = 262
# [INFO] update_w
#  [2.22628738 0.91430088 0.38259669]
# [INFO] loop count = 263
# [INFO] update_w
#  [2.2276814  0.91255895 0.38290935]
# [INFO] loop count = 264
# [INFO] update_w
#  [2.22907338 0.91082041 0.38322132]
# [INFO] loop count = 265
# [INFO] update_w
#  [2.23046334 0.90908525 0.38353259]
# [INFO] loop count = 266
# [INFO] update_w
#  [2.23185128 0.90735345 0.38384317]
# [INFO] loop count = 267
# [INFO] update_w
#  [2.2332372  0.90562503 0.38415306]
# [INFO] loop count = 268
# [INFO] update_w
#  [2.2346211  0.90389996 0.38446226]
# [INFO] loop count = 269
# [INFO] update_w
#  [2.236003   0.90217824 0.38477077]
# [INFO] loop count = 270
# [INFO] update_w
#  [2.23738288 0.90045987 0.3850786 ]
# [INFO] loop count = 271
# [INFO] update_w
#  [2.23876075 0.89874485 0.38538573]
# [INFO] loop count = 272
# [INFO] update_w
#  [2.24013663 0.89703316 0.38569219]
# [INFO] loop count = 273
# [INFO] update_w
#  [2.24151051 0.89532479 0.38599796]
# [INFO] loop count = 274
# [INFO] update_w
#  [2.24288239 0.89361975 0.38630304]
# [INFO] loop count = 275
# [INFO] update_w
#  [2.24425228 0.89191803 0.38660745]
# [INFO] loop count = 276
# [INFO] update_w
#  [2.24562018 0.89021962 0.38691118]
# [INFO] loop count = 277
# [INFO] update_w
#  [2.2469861  0.88852451 0.38721422]
# [INFO] loop count = 278
# [INFO] update_w
#  [2.24835004 0.8868327  0.38751659]
# [INFO] loop count = 279
# [INFO] update_w
#  [2.249712   0.88514419 0.38781829]
# [INFO] loop count = 280
# [INFO] update_w
#  [2.25107199 0.88345896 0.38811931]
# [INFO] loop count = 281
# [INFO] update_w
#  [2.25243001 0.88177701 0.38841965]
# [INFO] loop count = 282
# [INFO] update_w
#  [2.25378606 0.88009834 0.38871933]
# [INFO] loop count = 283
# [INFO] update_w
#  [2.25514015 0.87842293 0.38901833]
# [INFO] loop count = 284
# [INFO] update_w
#  [2.25649228 0.8767508  0.38931666]
# [INFO] loop count = 285
# [INFO] update_w
#  [2.25784245 0.87508191 0.38961433]
# [INFO] loop count = 286
# [INFO] update_w
#  [2.25919067 0.87341628 0.38991132]
# [INFO] loop count = 287
# [INFO] update_w
#  [2.26053694 0.8717539  0.39020765]
# [INFO] loop count = 288
# [INFO] update_w
#  [2.26188127 0.87009475 0.39050332]
# [INFO] loop count = 289
# [INFO] update_w
#  [2.26322365 0.86843884 0.39079832]
# [INFO] loop count = 290
# [INFO] update_w
#  [2.26456409 0.86678616 0.39109265]
# [INFO] loop count = 291
# [INFO] update_w
#  [2.2659026  0.8651367  0.39138633]
# [INFO] loop count = 292
# [INFO] update_w
#  [2.26723918 0.86349045 0.39167935]
# [INFO] loop count = 293
# [INFO] update_w
#  [2.26857382 0.86184742 0.39197171]
# [INFO] loop count = 294
# [INFO] update_w
#  [2.26990655 0.86020759 0.3922634 ]
# [INFO] loop count = 295
# [INFO] update_w
#  [2.27123735 0.85857096 0.39255445]
# [INFO] loop count = 296
# [INFO] update_w
#  [2.27256623 0.85693752 0.39284483]
# [INFO] loop count = 297
# [INFO] update_w
#  [2.27389319 0.85530728 0.39313457]
# [INFO] loop count = 298
# [INFO] update_w
#  [2.27521825 0.85368021 0.39342365]
# [INFO] loop count = 299
# [INFO] update_w
#  [2.27654139 0.85205632 0.39371208]
# [INFO] loop count = 300
# [INFO] update_w
#  [2.27786263 0.85043559 0.39399985]
# [INFO] loop count = 301
# [INFO] update_w
#  [2.27918197 0.84881804 0.39428698]
# [INFO] loop count = 302
# [INFO] update_w
#  [2.28049941 0.84720364 0.39457346]
# [INFO] loop count = 303
# [INFO] update_w
#  [2.28181496 0.84559239 0.39485929]
# [INFO] loop count = 304
# [INFO] update_w
#  [2.28312861 0.8439843  0.39514448]
# [INFO] loop count = 305
# [INFO] update_w
#  [2.28444038 0.84237934 0.39542902]
# [INFO] loop count = 306
# [INFO] update_w
#  [2.28575026 0.84077752 0.39571292]
# [INFO] loop count = 307
# [INFO] update_w
#  [2.28705826 0.83917883 0.39599618]
# [INFO] loop count = 308
# [INFO] update_w
#  [2.28836438 0.83758326 0.39627879]
# [INFO] loop count = 309
# [INFO] update_w
#  [2.28966863 0.83599082 0.39656077]
# [INFO] loop count = 310
# [INFO] update_w
#  [2.290971   0.83440148 0.3968421 ]
# [INFO] loop count = 311
# [INFO] update_w
#  [2.29227151 0.83281526 0.3971228 ]
# [INFO] loop count = 312
# [INFO] update_w
#  [2.29357015 0.83123213 0.39740286]
# [INFO] loop count = 313
# [INFO] update_w
#  [2.29486693 0.82965211 0.39768229]
# [INFO] loop count = 314
# [INFO] update_w
#  [2.29616185 0.82807517 0.39796108]
# [INFO] loop count = 315
# [INFO] update_w
#  [2.29745492 0.82650132 0.39823924]
# [INFO] loop count = 316
# [INFO] update_w
#  [2.29874613 0.82493055 0.39851676]
# [INFO] loop count = 317
# [INFO] update_w
#  [2.30003549 0.82336285 0.39879366]
# [INFO] loop count = 318
# [INFO] update_w
#  [2.30132301 0.82179822 0.39906993]
# [INFO] loop count = 319
# [INFO] update_w
#  [2.30260869 0.82023666 0.39934556]
# [INFO] loop count = 320
# [INFO] update_w
#  [2.30389253 0.81867815 0.39962058]
# [INFO] loop count = 321
# [INFO] update_w
#  [2.30517453 0.81712269 0.39989496]
# [INFO] loop count = 322
# [INFO] update_w
#  [2.3064547  0.81557028 0.40016872]
# [INFO] loop count = 323
# [INFO] update_w
#  [2.30773304 0.81402091 0.40044185]
# [INFO] loop count = 324
# [INFO] update_w
#  [2.30900956 0.81247458 0.40071437]
# [INFO] loop count = 325
# [INFO] update_w
#  [2.31028425 0.81093128 0.40098626]
# [INFO] loop count = 326
# [INFO] update_w
#  [2.31155712 0.809391   0.40125753]
# [INFO] loop count = 327
# [INFO] update_w
#  [2.31282818 0.80785374 0.40152818]
# [INFO] loop count = 328
# [INFO] update_w
#  [2.31409742 0.80631949 0.40179821]
# [INFO] loop count = 329
# [INFO] update_w
#  [2.31536486 0.80478825 0.40206763]
# [INFO] loop count = 330
# [INFO] update_w
#  [2.31663049 0.80326001 0.40233643]
# [INFO] loop count = 331
# [INFO] update_w
#  [2.31789431 0.80173478 0.40260461]
# [INFO] loop count = 332
# [INFO] update_w
#  [2.31915633 0.80021253 0.40287219]
# [INFO] loop count = 333
# [INFO] update_w
#  [2.32041656 0.79869327 0.40313915]
# [INFO] loop count = 334
# [INFO] update_w
#  [2.32167499 0.79717699 0.40340549]
# [INFO] loop count = 335
# [INFO] update_w
#  [2.32293163 0.79566368 0.40367123]
# [INFO] loop count = 336
# [INFO] update_w
#  [2.32418648 0.79415335 0.40393636]
# [INFO] loop count = 337
# [INFO] update_w
#  [2.32543955 0.79264598 0.40420088]
# [INFO] loop count = 338
# [INFO] update_w
#  [2.32669084 0.79114157 0.40446479]
# [INFO] loop count = 339
# [INFO] update_w
#  [2.32794035 0.78964011 0.4047281 ]
# [INFO] loop count = 340
# [INFO] update_w
#  [2.32918808 0.7881416  0.4049908 ]
# [INFO] loop count = 341
# [INFO] update_w
#  [2.33043404 0.78664604 0.4052529 ]
# [INFO] loop count = 342
# [INFO] update_w
#  [2.33167824 0.78515341 0.40551439]
# [INFO] loop count = 343
# [INFO] update_w
#  [2.33292066 0.78366372 0.40577529]
# [INFO] loop count = 344
# [INFO] update_w
#  [2.33416133 0.78217695 0.40603558]
# [INFO] loop count = 345
# [INFO] update_w
#  [2.33540023 0.78069311 0.40629527]
# [INFO] loop count = 346
# [INFO] update_w
#  [2.33663738 0.77921218 0.40655437]
# [INFO] loop count = 347
# [INFO] update_w
#  [2.33787278 0.77773417 0.40681287]
# [INFO] loop count = 348
# [INFO] update_w
#  [2.33910642 0.77625906 0.40707077]
# [INFO] loop count = 349
# [INFO] update_w
#  [2.34033832 0.77478685 0.40732808]
# [INFO] loop count = 350
# [INFO] update_w
#  [2.34156847 0.77331754 0.4075848 ]
# [INFO] loop count = 351
# [INFO] update_w
#  [2.34279689 0.77185112 0.40784092]
# [INFO] loop count = 352
# [INFO] update_w
#  [2.34402356 0.77038758 0.40809645]
# [INFO] loop count = 353
# [INFO] update_w
#  [2.3452485  0.76892692 0.40835139]
# [INFO] loop count = 354
# [INFO] update_w
#  [2.34647171 0.76746914 0.40860574]
# [INFO] loop count = 355
# [INFO] update_w
#  [2.34769319 0.76601423 0.4088595 ]
# [INFO] loop count = 356
# [INFO] update_w
#  [2.34891294 0.76456218 0.40911267]
# [INFO] loop count = 357
# [INFO] update_w
#  [2.35013097 0.76311299 0.40936526]
# [INFO] loop count = 358
# [INFO] update_w
#  [2.35134729 0.76166666 0.40961726]
# [INFO] loop count = 359
# [INFO] update_w
#  [2.35256188 0.76022317 0.40986868]
# [INFO] loop count = 360
# [INFO] update_w
#  [2.35377476 0.75878253 0.41011952]
# [INFO] loop count = 361
# [INFO] update_w
#  [2.35498593 0.75734473 0.41036977]
# [INFO] loop count = 362
# [INFO] update_w
#  [2.3561954  0.75590976 0.41061944]
# [INFO] loop count = 363
# [INFO] update_w
#  [2.35740315 0.75447762 0.41086853]
# [INFO] loop count = 364
# [INFO] update_w
#  [2.35860921 0.7530483  0.41111705]
# [INFO] loop count = 365
# [INFO] update_w
#  [2.35981357 0.7516218  0.41136498]
# [INFO] loop count = 366
# [INFO] update_w
#  [2.36101623 0.75019812 0.41161234]
# [INFO] loop count = 367
# [INFO] update_w
#  [2.3622172  0.74877724 0.41185913]
# [INFO] loop count = 368
# [INFO] update_w
#  [2.36341648 0.74735916 0.41210533]
# [INFO] loop count = 369
# [INFO] update_w
#  [2.36461408 0.74594389 0.41235097]
# [INFO] loop count = 370
# [INFO] update_w
#  [2.36580999 0.7445314  0.41259603]
# [INFO] loop count = 371
# [INFO] update_w
#  [2.36700422 0.7431217  0.41284052]
# [INFO] loop count = 372
# [INFO] update_w
#  [2.36819677 0.74171479 0.41308445]
# [INFO] loop count = 373
# [INFO] update_w
#  [2.36938765 0.74031065 0.4133278 ]
# [INFO] loop count = 374
# [INFO] update_w
#  [2.37057685 0.73890929 0.41357058]
# [INFO] loop count = 375
# [INFO] update_w
#  [2.37176439 0.73751069 0.4138128 ]
# [INFO] loop count = 376
# [INFO] update_w
#  [2.37295026 0.73611486 0.41405445]
# [INFO] loop count = 377
# [INFO] update_w
#  [2.37413447 0.73472178 0.41429553]
# [INFO] loop count = 378
# [INFO] update_w
#  [2.37531701 0.73333146 0.41453605]
# [INFO] loop count = 379
# [INFO] update_w
#  [2.3764979  0.73194388 0.41477601]
# [INFO] loop count = 380
# [INFO] update_w
#  [2.37767714 0.73055905 0.4150154 ]
# [INFO] loop count = 381
# [INFO] update_w
#  [2.37885472 0.72917695 0.41525424]
# [INFO] loop count = 382
# [INFO] update_w
#  [2.38003066 0.72779759 0.41549251]
# [INFO] loop count = 383
# [INFO] update_w
#  [2.38120495 0.72642095 0.41573023]
# [INFO] loop count = 384
# [INFO] update_w
#  [2.3823776  0.72504704 0.41596738]
# [INFO] loop count = 385
# [INFO] update_w
#  [2.38354861 0.72367584 0.41620398]
# [INFO] loop count = 386
# [INFO] update_w
#  [2.38471798 0.72230736 0.41644003]
# [INFO] loop count = 387
# [INFO] update_w
#  [2.38588572 0.72094159 0.41667551]
# [INFO] loop count = 388
# [INFO] update_w
#  [2.38705182 0.71957852 0.41691045]
# [INFO] loop count = 389
# [INFO] update_w
#  [2.3882163  0.71821815 0.41714483]
# [INFO] loop count = 390
# [INFO] update_w
#  [2.38937916 0.71686047 0.41737866]
# [INFO] loop count = 391
# [INFO] update_w
#  [2.39054039 0.71550548 0.41761194]
# [INFO] loop count = 392
# [INFO] update_w
#  [2.3917     0.71415317 0.41784467]
# [INFO] loop count = 393
# [INFO] update_w
#  [2.39285799 0.71280354 0.41807685]
# [INFO] loop count = 394
# [INFO] update_w
#  [2.39401437 0.71145659 0.41830848]
# [INFO] loop count = 395
# [INFO] update_w
#  [2.39516914 0.7101123  0.41853957]
# [INFO] loop count = 396
# [INFO] update_w
#  [2.3963223  0.70877068 0.41877011]
# [INFO] loop count = 397
# [INFO] update_w
#  [2.39747386 0.70743172 0.4190001 ]
# [INFO] loop count = 398
# [INFO] update_w
#  [2.39862381 0.70609541 0.41922955]
# [INFO] loop count = 399
# [INFO] update_w
#  [2.39977216 0.70476175 0.41945846]
# [INFO] loop count = 400
# [INFO] update_w
#  [2.40091892 0.70343074 0.41968683]
# [INFO] loop count = 401
# [INFO] update_w
#  [2.40206408 0.70210237 0.41991465]
# [INFO] loop count = 402
# [INFO] update_w
#  [2.40320765 0.70077663 0.42014194]
# [INFO] loop count = 403
# [INFO] update_w
#  [2.40434963 0.69945353 0.42036868]
# [INFO] loop count = 404
# [INFO] update_w
#  [2.40549003 0.69813305 0.42059489]
# [INFO] loop count = 405
# [INFO] update_w
#  [2.40662884 0.69681519 0.42082056]
# [INFO] loop count = 406
# [INFO] update_w
#  [2.40776608 0.69549994 0.4210457 ]
# [INFO] loop count = 407
# [INFO] update_w
#  [2.40890173 0.69418731 0.4212703 ]
# [INFO] loop count = 408
# [INFO] update_w
#  [2.41003581 0.69287729 0.42149437]
# [INFO] loop count = 409
# [INFO] update_w
#  [2.41116832 0.69156987 0.4217179 ]
# [INFO] loop count = 410
# [INFO] update_w
#  [2.41229926 0.69026504 0.4219409 ]
# [INFO] loop count = 411
# [INFO] update_w
#  [2.41342864 0.68896281 0.42216337]
# [INFO] loop count = 412
# [INFO] update_w
#  [2.41455645 0.68766317 0.42238531]
# [INFO] loop count = 413
# [INFO] update_w
#  [2.4156827  0.68636611 0.42260672]
# [INFO] loop count = 414
# [INFO] update_w
#  [2.41680739 0.68507163 0.4228276 ]
# [INFO] loop count = 415
# [INFO] update_w
#  [2.41793052 0.68377972 0.42304796]
# [INFO] loop count = 416
# [INFO] update_w
#  [2.41905211 0.68249038 0.42326779]
# [INFO] loop count = 417
# [INFO] update_w
#  [2.42017214 0.68120361 0.42348709]
# [INFO] loop count = 418
# [INFO] update_w
#  [2.42129063 0.6799194  0.42370587]
# [INFO] loop count = 419
# [INFO] update_w
#  [2.42240757 0.67863774 0.42392413]
# [INFO] loop count = 420
# [INFO] update_w
#  [2.42352297 0.67735863 0.42414186]
# [INFO] loop count = 421
# [INFO] update_w
#  [2.42463683 0.67608207 0.42435907]
# [INFO] loop count = 422
# [INFO] update_w
#  [2.42574916 0.67480806 0.42457577]
# [INFO] loop count = 423
# [INFO] update_w
#  [2.42685995 0.67353657 0.42479194]
# [INFO] loop count = 424
# [INFO] update_w
#  [2.42796921 0.67226762 0.42500759]
# [INFO] loop count = 425
# [INFO] update_w
#  [2.42907694 0.6710012  0.42522273]
# [INFO] loop count = 426
# [INFO] update_w
#  [2.43018314 0.66973731 0.42543735]
# [INFO] loop count = 427
# [INFO] update_w
#  [2.43128783 0.66847593 0.42565145]
# [INFO] loop count = 428
# [INFO] update_w
#  [2.43239099 0.66721706 0.42586504]
# [INFO] loop count = 429
# [INFO] update_w
#  [2.43349264 0.6659607  0.42607811]
# [INFO] loop count = 430
# [INFO] update_w
#  [2.43459277 0.66470685 0.42629068]
# [INFO] loop count = 431
# [INFO] update_w
#  [2.43569139 0.6634555  0.42650273]
# [INFO] loop count = 432
# [INFO] update_w
#  [2.4367885  0.66220665 0.42671427]
# [INFO] loop count = 433
# [INFO] update_w
#  [2.4378841  0.66096029 0.42692529]
# [INFO] loop count = 434
# [INFO] update_w
#  [2.4389782  0.65971641 0.42713581]
# [INFO] loop count = 435
# [INFO] update_w
#  [2.44007079 0.65847502 0.42734583]
# [INFO] loop count = 436
# [INFO] update_w
#  [2.44116189 0.6572361  0.42755533]
# [INFO] loop count = 437
# [INFO] update_w
#  [2.44225149 0.65599966 0.42776433]
# [INFO] loop count = 438
# [INFO] update_w
#  [2.4433396  0.65476569 0.42797282]
# [INFO] loop count = 439
# [INFO] update_w
#  [2.44442622 0.65353418 0.42818081]
# [INFO] loop count = 440
# [INFO] update_w
#  [2.44551135 0.65230513 0.42838829]
# [INFO] loop count = 441
# [INFO] update_w
#  [2.44659499 0.65107854 0.42859527]
# [INFO] loop count = 442
# [INFO] update_w
#  [2.44767715 0.64985439 0.42880175]
# [INFO] loop count = 443
# [INFO] update_w
#  [2.44875783 0.6486327  0.42900773]
# [INFO] loop count = 444
# [INFO] update_w
#  [2.44983703 0.64741345 0.42921321]
# [INFO] loop count = 445
# [INFO] update_w
#  [2.45091475 0.64619663 0.42941819]
# [INFO] loop count = 446
# [INFO] update_w
#  [2.45199101 0.64498225 0.42962267]
# [INFO] loop count = 447
# [INFO] update_w
#  [2.45306579 0.6437703  0.42982666]
# [INFO] loop count = 448
# [INFO] update_w
#  [2.4541391  0.64256077 0.43003015]
# [INFO] loop count = 449
# [INFO] update_w
#  [2.45521095 0.64135366 0.43023314]
# [INFO] loop count = 450
# [INFO] update_w
#  [2.45628134 0.64014897 0.43043564]
# [INFO] loop count = 451
# [INFO] update_w
#  [2.45735027 0.63894669 0.43063764]
# [INFO] loop count = 452
# [INFO] update_w
#  [2.45841774 0.63774681 0.43083916]
# [INFO] loop count = 453
# [INFO] update_w
#  [2.45948375 0.63654934 0.43104018]
# [INFO] loop count = 454
# [INFO] update_w
#  [2.46054831 0.63535427 0.43124071]
# [INFO] loop count = 455
# [INFO] update_w
#  [2.46161143 0.63416159 0.43144075]
# [INFO] loop count = 456
# [INFO] update_w
#  [2.46267309 0.6329713  0.4316403 ]
# [INFO] loop count = 457
# [INFO] update_w
#  [2.46373331 0.6317834  0.43183936]
# [INFO] loop count = 458
# [INFO] update_w
#  [2.46479209 0.63059788 0.43203794]
# [INFO] loop count = 459
# [INFO] update_w
#  [2.46584943 0.62941473 0.43223603]
# [INFO] loop count = 460
# [INFO] update_w
#  [2.46690534 0.62823396 0.43243363]
# [INFO] loop count = 461
# [INFO] update_w
#  [2.4679598  0.62705555 0.43263075]
# [INFO] loop count = 462
# [INFO] update_w
#  [2.46901284 0.62587951 0.43282738]
# [INFO] loop count = 463
# [INFO] update_w
#  [2.47006445 0.62470583 0.43302354]
# [INFO] loop count = 464
# [INFO] update_w
#  [2.47111463 0.6235345  0.43321921]
# [INFO] loop count = 465
# [INFO] update_w
#  [2.47216338 0.62236553 0.4334144 ]
# [INFO] loop count = 466
# [INFO] update_w
#  [2.47321071 0.6211989  0.43360911]
# [INFO] loop count = 467
# [INFO] update_w
#  [2.47425663 0.62003461 0.43380334]
# [INFO] loop count = 468
# [INFO] update_w
#  [2.47530112 0.61887266 0.43399709]
# [INFO] loop count = 469
# [INFO] update_w
#  [2.47634421 0.61771305 0.43419036]
# [INFO] loop count = 470
# [INFO] update_w
#  [2.47738588 0.61655576 0.43438316]
# [INFO] loop count = 471
# [INFO] update_w
#  [2.47842614 0.6154008  0.43457548]
# [INFO] loop count = 472
# [INFO] update_w
#  [2.47946499 0.61424817 0.43476733]
# [INFO] loop count = 473
# [INFO] update_w
#  [2.48050244 0.61309785 0.4349587 ]
# [INFO] loop count = 474
# [INFO] update_w
#  [2.48153849 0.61194984 0.4351496 ]
# [INFO] loop count = 475
# [INFO] update_w
#  [2.48257314 0.61080414 0.43534003]
# [INFO] loop count = 476
# [INFO] update_w
#  [2.48360639 0.60966074 0.43552999]
# [INFO] loop count = 477
# [INFO] update_w
#  [2.48463824 0.60851965 0.43571947]
# [INFO] loop count = 478
# [INFO] update_w
#  [2.4856687  0.60738085 0.43590849]
# [INFO] loop count = 479
# [INFO] update_w
#  [2.48669778 0.60624435 0.43609704]
# [INFO] loop count = 480
# [INFO] update_w
#  [2.48772546 0.60511013 0.43628512]
# [INFO] loop count = 481
# [INFO] update_w
#  [2.48875176 0.6039782  0.43647273]
# [INFO] loop count = 482
# [INFO] update_w
#  [2.48977668 0.60284854 0.43665988]
# [INFO] loop count = 483
# [INFO] update_w
#  [2.49080022 0.60172116 0.43684656]
# [INFO] loop count = 484
# [INFO] update_w
#  [2.49182238 0.60059605 0.43703277]
# [INFO] loop count = 485
# [INFO] update_w
#  [2.49284317 0.59947321 0.43721852]
# [INFO] loop count = 486
# [INFO] update_w
#  [2.49386258 0.59835264 0.43740381]
# [INFO] loop count = 487
# [INFO] update_w
#  [2.49488062 0.59723432 0.43758864]
# [INFO] loop count = 488
# [INFO] update_w
#  [2.49589729 0.59611826 0.43777301]
# [INFO] loop count = 489
# [INFO] update_w
#  [2.4969126  0.59500444 0.43795691]
# [INFO] loop count = 490
# [INFO] update_w
#  [2.49792655 0.59389288 0.43814036]
# [INFO] loop count = 491
# [INFO] update_w
#  [2.49893913 0.59278355 0.43832335]
# [INFO] loop count = 492
# [INFO] update_w
#  [2.49995036 0.59167647 0.43850588]
# [INFO] loop count = 493
# [INFO] update_w
#  [2.50096022 0.59057162 0.43868795]
# [INFO] loop count = 494
# [INFO] update_w
#  [2.50196874 0.589469   0.43886957]
# [INFO] loop count = 495
# [INFO] update_w
#  [2.5029759  0.58836861 0.43905073]
# [INFO] loop count = 496
# [INFO] update_w
#  [2.50398172 0.58727044 0.43923144]
# [INFO] loop count = 497
# [INFO] update_w
#  [2.50498619 0.58617449 0.43941169]
# [INFO] loop count = 498
# [INFO] update_w
#  [2.50598931 0.58508075 0.4395915 ]
# [INFO] loop count = 499
# [INFO] update_w
#  [2.50699109 0.58398922 0.43977085]
# [INFO] loop count = 500
# [INFO] update_w
#  [2.50799154 0.5828999  0.43994974]
# [INFO] loop count = 501
# [INFO] update_w
#  [2.50899064 0.58181278 0.44012819]
# [INFO] loop count = 502
# [INFO] update_w
#  [2.50998841 0.58072786 0.44030619]
# [INFO] loop count = 503
# [INFO] update_w
#  [2.51098485 0.57964514 0.44048374]
# [INFO] loop count = 504
# [INFO] update_w
#  [2.51197996 0.5785646  0.44066084]
# [INFO] loop count = 505
# [INFO] update_w
#  [2.51297374 0.57748625 0.4408375 ]
# [INFO] loop count = 506
# [INFO] update_w
#  [2.51396619 0.57641008 0.44101371]
# [INFO] loop count = 507
# [INFO] update_w
#  [2.51495732 0.5753361  0.44118947]
# [INFO] loop count = 508
# [INFO] update_w
#  [2.51594713 0.57426428 0.44136479]
# [INFO] loop count = 509
# [INFO] update_w
#  [2.51693563 0.57319464 0.44153967]
# [INFO] loop count = 510
# [INFO] update_w
#  [2.5179228  0.57212717 0.4417141 ]
# [INFO] loop count = 511
# [INFO] update_w
#  [2.51890866 0.57106185 0.44188809]
# [INFO] loop count = 512
# [INFO] update_w
#  [2.51989321 0.5699987  0.44206164]
# [INFO] loop count = 513
# [INFO] update_w
#  [2.52087645 0.5689377  0.44223475]
# [INFO] loop count = 514
# [INFO] update_w
#  [2.52185838 0.56787885 0.44240742]
# [INFO] loop count = 515
# [INFO] update_w
#  [2.52283901 0.56682215 0.44257965]
# [INFO] loop count = 516
# [INFO] update_w
#  [2.52381834 0.56576759 0.44275144]
# [INFO] loop count = 517
# [INFO] update_w
#  [2.52479636 0.56471517 0.4429228 ]
# [INFO] loop count = 518
# [INFO] update_w
#  [2.52577309 0.56366489 0.44309372]
# [INFO] loop count = 519
# [INFO] update_w
#  [2.52674852 0.56261674 0.4432642 ]
# [INFO] loop count = 520
# [INFO] update_w
#  [2.52772266 0.56157071 0.44343425]
# [INFO] loop count = 521
# [INFO] update_w
#  [2.52869551 0.56052681 0.44360387]
# [INFO] loop count = 522
# [INFO] update_w
#  [2.52966707 0.55948503 0.44377305]
# [INFO] loop count = 523
# [INFO] update_w
#  [2.53063734 0.55844537 0.4439418 ]
# [INFO] loop count = 524
# [INFO] update_w
#  [2.53160633 0.55740782 0.44411011]
# [INFO] loop count = 525
# [INFO] update_w
#  [2.53257403 0.55637237 0.444278  ]
# [INFO] loop count = 526
# [INFO] update_w
#  [2.53354046 0.55533904 0.44444546]
# [INFO] loop count = 527
# [INFO] update_w
#  [2.53450561 0.5543078  0.44461249]
# [INFO] loop count = 528
# [INFO] update_w
#  [2.53546948 0.55327866 0.44477909]
# [INFO] loop count = 529
# [INFO] update_w
#  [2.53643208 0.55225161 0.44494526]
# [INFO] loop count = 530
# [INFO] update_w
#  [2.53739341 0.55122665 0.445111  ]
# [INFO] loop count = 531
# [INFO] update_w
#  [2.53835346 0.55020378 0.44527632]
# [INFO] loop count = 532
# [INFO] update_w
#  [2.53931226 0.54918299 0.44544121]
# [INFO] loop count = 533
# [INFO] update_w
#  [2.54026979 0.54816428 0.44560568]
# [INFO] loop count = 534
# [INFO] update_w
#  [2.54122605 0.54714764 0.44576973]
# [INFO] loop count = 535
# [INFO] update_w
#  [2.54218106 0.54613307 0.44593335]
# [INFO] loop count = 536
# [INFO] update_w
#  [2.54313481 0.54512057 0.44609655]
# [INFO] loop count = 537
# [INFO] update_w
#  [2.5440873  0.54411014 0.44625933]
# [INFO] loop count = 538
# [INFO] update_w
#  [2.54503854 0.54310176 0.44642168]
# [INFO] loop count = 539
# [INFO] update_w
#  [2.54598853 0.54209544 0.44658362]
# [INFO] loop count = 540
# [INFO] update_w
#  [2.54693727 0.54109116 0.44674514]
# [INFO] loop count = 541
# [INFO] update_w
#  [2.54788477 0.54008894 0.44690624]
# [INFO] loop count = 542
# [INFO] update_w
#  [2.54883102 0.53908876 0.44706692]
# [INFO] loop count = 543
# [INFO] update_w
#  [2.54977602 0.53809063 0.44722719]
# [INFO] loop count = 544
# [INFO] update_w
#  [2.55071979 0.53709453 0.44738704]
# [INFO] loop count = 545
# [INFO] update_w
#  [2.55166232 0.53610046 0.44754648]
# [INFO] loop count = 546
# [INFO] update_w
#  [2.55260361 0.53510842 0.4477055 ]
# [INFO] loop count = 547
# [INFO] update_w
#  [2.55354367 0.53411841 0.4478641 ]
# [INFO] loop count = 548
# [INFO] update_w
#  [2.5544825  0.53313042 0.4480223 ]
# [INFO] loop count = 549
# [INFO] update_w
#  [2.55542009 0.53214445 0.44818008]
# [INFO] loop count = 550
# [INFO] update_w
#  [2.55635647 0.5311605  0.44833745]
# [INFO] loop count = 551
# [INFO] update_w
#  [2.55729161 0.53017855 0.44849441]
# [INFO] loop count = 552
# [INFO] update_w
#  [2.55822553 0.52919862 0.44865096]
# [INFO] loop count = 553
# [INFO] update_w
#  [2.55915824 0.52822068 0.4488071 ]
# [INFO] loop count = 554
# [INFO] update_w
#  [2.56008972 0.52724475 0.44896283]
# [INFO] loop count = 555
# [INFO] update_w
#  [2.56101999 0.52627082 0.44911815]
# [INFO] loop count = 556
# [INFO] update_w
#  [2.56194904 0.52529887 0.44927307]
# [INFO] loop count = 557
# [INFO] update_w
#  [2.56287688 0.52432892 0.44942758]
# [INFO] loop count = 558
# [INFO] update_w
#  [2.56380351 0.52336095 0.44958169]
# [INFO] loop count = 559
# [INFO] update_w
#  [2.56472893 0.52239497 0.44973539]
# [INFO] loop count = 560
# [INFO] update_w
#  [2.56565315 0.52143096 0.44988868]
# [INFO] loop count = 561
# [INFO] update_w
#  [2.56657616 0.52046893 0.45004158]
# [INFO] loop count = 562
# [INFO] update_w
#  [2.56749797 0.51950887 0.45019407]
# [INFO] loop count = 563
# [INFO] update_w
#  [2.56841858 0.51855078 0.45034616]
# [INFO] loop count = 564
# [INFO] update_w
#  [2.569338   0.51759466 0.45049785]
# [INFO] loop count = 565
# [INFO] update_w
#  [2.57025621 0.51664049 0.45064914]
# [INFO] loop count = 566
# [INFO] update_w
#  [2.57117324 0.51568828 0.45080002]
# [INFO] loop count = 567
# [INFO] update_w
#  [2.57208907 0.51473803 0.45095051]
# [INFO] loop count = 568
# [INFO] update_w
#  [2.57300372 0.51378972 0.45110061]
# [INFO] loop count = 569
# [INFO] update_w
#  [2.57391717 0.51284336 0.4512503 ]
# [INFO] loop count = 570
# [INFO] update_w
#  [2.57482945 0.51189895 0.4513996 ]
# [INFO] loop count = 571
# [INFO] update_w
#  [2.57574054 0.51095647 0.4515485 ]
# [INFO] loop count = 572
# [INFO] update_w
#  [2.57665044 0.51001593 0.45169701]
# [INFO] loop count = 573
# [INFO] update_w
#  [2.57755917 0.50907732 0.45184512]
# [INFO] loop count = 574
# [INFO] update_w
#  [2.57846673 0.50814065 0.45199284]
# [INFO] loop count = 575
# [INFO] update_w
#  [2.5793731  0.50720589 0.45214017]
# [INFO] loop count = 576
# [INFO] update_w
#  [2.58027831 0.50627306 0.4522871 ]
# [INFO] loop count = 577
# [INFO] update_w
#  [2.58118234 0.50534215 0.45243364]
# [INFO] loop count = 578
# [INFO] update_w
#  [2.58208521 0.50441315 0.4525798 ]
# [INFO] loop count = 579
# [INFO] update_w
#  [2.58298691 0.50348607 0.45272556]
# [INFO] loop count = 580
# [INFO] update_w
#  [2.58388745 0.50256089 0.45287093]
# [INFO] loop count = 581
# [INFO] update_w
#  [2.58478682 0.50163762 0.45301592]
# [INFO] loop count = 582
# [INFO] update_w
#  [2.58568503 0.50071625 0.45316051]
# [INFO] loop count = 583
# [INFO] update_w
#  [2.58658209 0.49979677 0.45330472]
# [INFO] loop count = 584
# [INFO] update_w
#  [2.58747798 0.49887919 0.45344854]
# [INFO] loop count = 585
# [INFO] update_w
#  [2.58837273 0.4979635  0.45359198]
# [INFO] loop count = 586
# [INFO] update_w
#  [2.58926632 0.4970497  0.45373503]
# [INFO] loop count = 587
# [INFO] update_w
#  [2.59015876 0.49613779 0.4538777 ]
# [INFO] loop count = 588
# [INFO] update_w
#  [2.59105005 0.49522775 0.45401998]
# [INFO] loop count = 589
# [INFO] update_w
#  [2.5919402  0.49431959 0.45416188]
# [INFO] loop count = 590
# [INFO] update_w
#  [2.5928292 0.4934133 0.4543034]
# [INFO] loop count = 591
# [INFO] update_w
#  [2.59371706 0.49250889 0.45444454]
# [INFO] loop count = 592
# [INFO] update_w
#  [2.59460378 0.49160634 0.45458529]
# [INFO] loop count = 593
# [INFO] update_w
#  [2.59548936 0.49070565 0.45472567]
# [INFO] loop count = 594
# [INFO] update_w
#  [2.5963738  0.48980683 0.45486567]
# [INFO] loop count = 595
# [INFO] update_w
#  [2.59725711 0.48890986 0.45500528]
# [INFO] loop count = 596
# [INFO] update_w
#  [2.59813929 0.48801475 0.45514452]
# [INFO] loop count = 597
# [INFO] update_w
#  [2.59902033 0.48712148 0.45528339]
# [INFO] loop count = 598
# [INFO] update_w
#  [2.59990025 0.48623006 0.45542187]
# [INFO] loop count = 599
# [INFO] update_w
#  [2.60077905 0.48534049 0.45555998]
# [INFO] loop count = 600
# [INFO] update_w
#  [2.60165671 0.48445276 0.45569772]
# [INFO] loop count = 601
# [INFO] update_w
#  [2.60253326 0.48356686 0.45583508]
# [INFO] loop count = 602
# [INFO] update_w
#  [2.60340868 0.48268279 0.45597206]
# [INFO] loop count = 603
# [INFO] update_w
#  [2.60428299 0.48180056 0.45610868]
# [INFO] loop count = 604
# [INFO] update_w
#  [2.60515618 0.48092015 0.45624492]
# [INFO] loop count = 605
# [INFO] update_w
#  [2.60602825 0.48004157 0.45638079]
# [INFO] loop count = 606
# [INFO] update_w
#  [2.60689921 0.4791648  0.45651628]
# [INFO] loop count = 607
# [INFO] update_w
#  [2.60776907 0.47828986 0.45665141]
# [INFO] loop count = 608
# [INFO] update_w
#  [2.60863781 0.47741672 0.45678617]
# [INFO] loop count = 609
# [INFO] update_w
#  [2.60950544 0.4765454  0.45692056]
# [INFO] loop count = 610
# [INFO] update_w
#  [2.61037197 0.47567588 0.45705458]
# [INFO] loop count = 611
# [INFO] update_w
#  [2.6112374  0.47480817 0.45718823]
# [INFO] loop count = 612
# [INFO] update_w
#  [2.61210172 0.47394226 0.45732152]
# [INFO] loop count = 613
# [INFO] update_w
#  [2.61296495 0.47307814 0.45745444]
# [INFO] loop count = 614
# [INFO] update_w
#  [2.61382708 0.47221582 0.45758699]
# [INFO] loop count = 615
# [INFO] update_w
#  [2.61468811 0.47135529 0.45771918]
# [INFO] loop count = 616
# [INFO] update_w
#  [2.61554805 0.47049654 0.457851  ]
# [INFO] loop count = 617
# [INFO] update_w
#  [2.6164069  0.46963958 0.45798246]
# [INFO] loop count = 618
# [INFO] update_w
#  [2.61726466 0.4687844  0.45811356]
# [INFO] loop count = 619
# [INFO] update_w
#  [2.61812133 0.467931   0.4582443 ]
# [INFO] loop count = 620
# [INFO] update_w
#  [2.61897692 0.46707937 0.45837467]
# [INFO] loop count = 621
# [INFO] update_w
#  [2.61983142 0.46622952 0.45850468]
# [INFO] loop count = 622
# [INFO] update_w
#  [2.62068484 0.46538143 0.45863434]
# [INFO] loop count = 623
# [INFO] update_w
#  [2.62153717 0.4645351  0.45876363]
# [INFO] loop count = 624
# [INFO] update_w
#  [2.62238843 0.46369054 0.45889256]
# [INFO] loop count = 625
# [INFO] update_w
#  [2.62323862 0.46284774 0.45902114]
# [INFO] loop count = 626
# [INFO] update_w
#  [2.62408773 0.46200669 0.45914936]
# [INFO] loop count = 627
# [INFO] update_w
#  [2.62493576 0.46116739 0.45927722]
# [INFO] loop count = 628
# [INFO] update_w
#  [2.62578273 0.46032984 0.45940472]
# [INFO] loop count = 629
# [INFO] update_w
#  [2.62662862 0.45949404 0.45953187]
# [INFO] loop count = 630
# [INFO] update_w
#  [2.62747345 0.45865998 0.45965867]
# [INFO] loop count = 631
# [INFO] update_w
#  [2.62831722 0.45782766 0.45978511]
# [INFO] loop count = 632
# [INFO] update_w
#  [2.62915992 0.45699707 0.45991119]
# ...
# [INFO] update_w
#  [4.39022117 0.67826655 0.16979467]
# [INFO] loop count = 9793
# [INFO] update_w
#  [4.39030202 0.67830921 0.16977215]
# [INFO] loop count = 9794
# [INFO] update_w
#  [4.39038286 0.67835186 0.16974965]
# [INFO] loop count = 9795
# [INFO] update_w
#  [4.39046368 0.67839451 0.16972714]
# [INFO] loop count = 9796
# [INFO] update_w
#  [4.3905445  0.67843715 0.16970464]
# [INFO] loop count = 9797
# [INFO] update_w
#  [4.39062531 0.67847978 0.16968213]
# [INFO] loop count = 9798
# [INFO] update_w
#  [4.3907061  0.67852241 0.16965964]
# [INFO] loop count = 9799
# [INFO] update_w
#  [4.39078688 0.67856504 0.16963714]
# [INFO] loop count = 9800
# [INFO] update_w
#  [4.39086766 0.67860765 0.16961465]
# [INFO] loop count = 9801
# [INFO] update_w
#  [4.39094842 0.67865027 0.16959216]
# [INFO] loop count = 9802
# [INFO] update_w
#  [4.39102917 0.67869287 0.16956968]
# [INFO] loop count = 9803
# [INFO] update_w
#  [4.39110991 0.67873547 0.16954719]
# [INFO] loop count = 9804
# [INFO] update_w
#  [4.39119064 0.67877807 0.16952471]
# [INFO] loop count = 9805
# [INFO] update_w
#  [4.39127136 0.67882066 0.16950224]
# [INFO] loop count = 9806
# [INFO] update_w
#  [4.39135207 0.67886324 0.16947976]
# [INFO] loop count = 9807
# [INFO] update_w
#  [4.39143277 0.67890582 0.16945729]
# [INFO] loop count = 9808
# [INFO] update_w
#  [4.39151346 0.67894839 0.16943483]
# [INFO] loop count = 9809
# [INFO] update_w
#  [4.39159414 0.67899096 0.16941236]
# [INFO] loop count = 9810
# [INFO] update_w
#  [4.3916748  0.67903352 0.1693899 ]
# [INFO] loop count = 9811
# [INFO] update_w
#  [4.39175546 0.67907608 0.16936744]
# [INFO] loop count = 9812
# [INFO] update_w
#  [4.3918361  0.67911863 0.16934499]
# [INFO] loop count = 9813
# [INFO] update_w
#  [4.39191674 0.67916117 0.16932253]
# [INFO] loop count = 9814
# [INFO] update_w
#  [4.39199736 0.67920371 0.16930008]
# [INFO] loop count = 9815
# [INFO] update_w
#  [4.39207797 0.67924624 0.16927764]
# [INFO] loop count = 9816
# [INFO] update_w
#  [4.39215858 0.67928877 0.16925519]
# [INFO] loop count = 9817
# [INFO] update_w
#  [4.39223917 0.67933129 0.16923275]
# [INFO] loop count = 9818
# [INFO] update_w
#  [4.39231975 0.67937381 0.16921031]
# [INFO] loop count = 9819
# [INFO] update_w
#  [4.39240032 0.67941632 0.16918788]
# [INFO] loop count = 9820
# [INFO] update_w
#  [4.39248088 0.67945882 0.16916545]
# [INFO] loop count = 9821
# [INFO] update_w
#  [4.39256143 0.67950132 0.16914302]
# [INFO] loop count = 9822
# [INFO] update_w
#  [4.39264196 0.67954382 0.16912059]
# [INFO] loop count = 9823
# [INFO] update_w
#  [4.39272249 0.67958631 0.16909817]
# [INFO] loop count = 9824
# [INFO] update_w
#  [4.39280301 0.67962879 0.16907575]
# [INFO] loop count = 9825
# [INFO] update_w
#  [4.39288351 0.67967126 0.16905333]
# [INFO] loop count = 9826
# [INFO] update_w
#  [4.39296401 0.67971374 0.16903092]
# [INFO] loop count = 9827
# [INFO] update_w
#  [4.39304449 0.6797562  0.16900851]
# [INFO] loop count = 9828
# [INFO] update_w
#  [4.39312497 0.67979866 0.1689861 ]
# [INFO] loop count = 9829
# [INFO] update_w
#  [4.39320543 0.67984112 0.16896369]
# [INFO] loop count = 9830
# [INFO] update_w
#  [4.39328588 0.67988356 0.16894129]
# [INFO] loop count = 9831
# [INFO] update_w
#  [4.39336633 0.67992601 0.16891889]
# [INFO] loop count = 9832
# [INFO] update_w
#  [4.39344676 0.67996844 0.16889649]
# [INFO] loop count = 9833
# [INFO] update_w
#  [4.39352718 0.68001088 0.1688741 ]
# [INFO] loop count = 9834
# [INFO] update_w
#  [4.39360759 0.6800533  0.16885171]
# [INFO] loop count = 9835
# [INFO] update_w
#  [4.39368799 0.68009572 0.16882932]
# [INFO] loop count = 9836
# [INFO] update_w
#  [4.39376838 0.68013814 0.16880694]
# [INFO] loop count = 9837
# [INFO] update_w
#  [4.39384875 0.68018055 0.16878456]
# [INFO] loop count = 9838
# [INFO] update_w
#  [4.39392912 0.68022295 0.16876218]
# [INFO] loop count = 9839
# [INFO] update_w
#  [4.39400948 0.68026535 0.1687398 ]
# [INFO] loop count = 9840
# [INFO] update_w
#  [4.39408982 0.68030774 0.16871743]
# [INFO] loop count = 9841
# [INFO] update_w
#  [4.39417016 0.68035013 0.16869506]
# [INFO] loop count = 9842
# [INFO] update_w
#  [4.39425048 0.68039251 0.16867269]
# [INFO] loop count = 9843
# [INFO] update_w
#  [4.3943308  0.68043488 0.16865033]
# [INFO] loop count = 9844
# [INFO] update_w
#  [4.3944111  0.68047725 0.16862797]
# [INFO] loop count = 9845
# [INFO] update_w
#  [4.39449139 0.68051962 0.16860561]
# [INFO] loop count = 9846
# [INFO] update_w
#  [4.39457168 0.68056198 0.16858326]
# [INFO] loop count = 9847
# [INFO] update_w
#  [4.39465195 0.68060433 0.16856091]
# [INFO] loop count = 9848
# [INFO] update_w
#  [4.39473221 0.68064668 0.16853856]
# [INFO] loop count = 9849
# [INFO] update_w
#  [4.39481246 0.68068902 0.16851621]
# [INFO] loop count = 9850
# [INFO] update_w
#  [4.3948927  0.68073135 0.16849387]
# [INFO] loop count = 9851
# [INFO] update_w
#  [4.39497293 0.68077369 0.16847153]
# [INFO] loop count = 9852
# [INFO] update_w
#  [4.39505314 0.68081601 0.16844919]
# [INFO] loop count = 9853
# [INFO] update_w
#  [4.39513335 0.68085833 0.16842686]
# [INFO] loop count = 9854
# [INFO] update_w
#  [4.39521355 0.68090064 0.16840453]
# [INFO] loop count = 9855
# [INFO] update_w
#  [4.39529374 0.68094295 0.1683822 ]
# [INFO] loop count = 9856
# [INFO] update_w
#  [4.39537391 0.68098525 0.16835987]
# [INFO] loop count = 9857
# [INFO] update_w
#  [4.39545408 0.68102755 0.16833755]
# [INFO] loop count = 9858
# [INFO] update_w
#  [4.39553423 0.68106984 0.16831523]
# [INFO] loop count = 9859
# [INFO] update_w
#  [4.39561438 0.68111213 0.16829292]
# [INFO] loop count = 9860
# [INFO] update_w
#  [4.39569451 0.68115441 0.1682706 ]
# [INFO] loop count = 9861
# [INFO] update_w
#  [4.39577463 0.68119668 0.16824829]
# [INFO] loop count = 9862
# [INFO] update_w
#  [4.39585474 0.68123895 0.16822598]
# [INFO] loop count = 9863
# [INFO] update_w
#  [4.39593484 0.68128121 0.16820368]
# [INFO] loop count = 9864
# [INFO] update_w
#  [4.39601494 0.68132347 0.16818138]
# [INFO] loop count = 9865
# [INFO] update_w
#  [4.39609502 0.68136572 0.16815908]
# [INFO] loop count = 9866
# [INFO] update_w
#  [4.39617508 0.68140797 0.16813678]
# [INFO] loop count = 9867
# [INFO] update_w
#  [4.39625514 0.68145021 0.16811449]
# [INFO] loop count = 9868
# [INFO] update_w
#  [4.39633519 0.68149245 0.1680922 ]
# [INFO] loop count = 9869
# [INFO] update_w
#  [4.39641523 0.68153468 0.16806992]
# [INFO] loop count = 9870
# [INFO] update_w
#  [4.39649526 0.6815769  0.16804763]
# [INFO] loop count = 9871
# [INFO] update_w
#  [4.39657527 0.68161912 0.16802535]
# [INFO] loop count = 9872
# [INFO] update_w
#  [4.39665528 0.68166133 0.16800307]
# [INFO] loop count = 9873
# [INFO] update_w
#  [4.39673527 0.68170354 0.1679808 ]
# [INFO] loop count = 9874
# [INFO] update_w
#  [4.39681526 0.68174574 0.16795853]
# [INFO] loop count = 9875
# [INFO] update_w
#  [4.39689523 0.68178794 0.16793626]
# [INFO] loop count = 9876
# [INFO] update_w
#  [4.3969752  0.68183013 0.16791399]
# [INFO] loop count = 9877
# [INFO] update_w
#  [4.39705515 0.68187231 0.16789173]
# [INFO] loop count = 9878
# [INFO] update_w
#  [4.39713509 0.68191449 0.16786947]
# [INFO] loop count = 9879
# [INFO] update_w
#  [4.39721502 0.68195667 0.16784721]
# [INFO] loop count = 9880
# [INFO] update_w
#  [4.39729494 0.68199883 0.16782496]
# [INFO] loop count = 9881
# [INFO] update_w
#  [4.39737485 0.682041   0.16780271]
# [INFO] loop count = 9882
# [INFO] update_w
#  [4.39745475 0.68208315 0.16778046]
# [INFO] loop count = 9883
# [INFO] update_w
#  [4.39753464 0.6821253  0.16775821]
# [INFO] loop count = 9884
# [INFO] update_w
#  [4.39761452 0.68216745 0.16773597]
# [INFO] loop count = 9885
# [INFO] update_w
#  [4.39769439 0.68220959 0.16771373]
# [INFO] loop count = 9886
# [INFO] update_w
#  [4.39777425 0.68225172 0.16769149]
# [INFO] loop count = 9887
# [INFO] update_w
#  [4.39785409 0.68229385 0.16766926]
# [INFO] loop count = 9888
# [INFO] update_w
#  [4.39793393 0.68233598 0.16764703]
# [INFO] loop count = 9889
# [INFO] update_w
#  [4.39801376 0.68237809 0.1676248 ]
# [INFO] loop count = 9890
# [INFO] update_w
#  [4.39809357 0.68242021 0.16760258]
# [INFO] loop count = 9891
# [INFO] update_w
#  [4.39817338 0.68246231 0.16758035]
# [INFO] loop count = 9892
# [INFO] update_w
#  [4.39825317 0.68250441 0.16755814]
# [INFO] loop count = 9893
# [INFO] update_w
#  [4.39833295 0.68254651 0.16753592]
# [INFO] loop count = 9894
# [INFO] update_w
#  [4.39841273 0.6825886  0.16751371]
# [INFO] loop count = 9895
# [INFO] update_w
#  [4.39849249 0.68263068 0.1674915 ]
# [INFO] loop count = 9896
# [INFO] update_w
#  [4.39857224 0.68267276 0.16746929]
# [INFO] loop count = 9897
# [INFO] update_w
#  [4.39865198 0.68271484 0.16744709]
# [INFO] loop count = 9898
# [INFO] update_w
#  [4.39873171 0.6827569  0.16742488]
# [INFO] loop count = 9899
# [INFO] update_w
#  [4.39881143 0.68279897 0.16740269]
# [INFO] loop count = 9900
# [INFO] update_w
#  [4.39889114 0.68284102 0.16738049]
# [INFO] loop count = 9901
# [INFO] update_w
#  [4.39897084 0.68288307 0.1673583 ]
# [INFO] loop count = 9902
# [INFO] update_w
#  [4.39905053 0.68292512 0.16733611]
# [INFO] loop count = 9903
# [INFO] update_w
#  [4.39913021 0.68296716 0.16731392]
# [INFO] loop count = 9904
# [INFO] update_w
#  [4.39920987 0.68300919 0.16729174]
# [INFO] loop count = 9905
# [INFO] update_w
#  [4.39928953 0.68305122 0.16726956]
# [INFO] loop count = 9906
# [INFO] update_w
#  [4.39936917 0.68309324 0.16724738]
# [INFO] loop count = 9907
# [INFO] update_w
#  [4.39944881 0.68313526 0.16722521]
# [INFO] loop count = 9908
# [INFO] update_w
#  [4.39952844 0.68317727 0.16720304]
# [INFO] loop count = 9909
# [INFO] update_w
#  [4.39960805 0.68321928 0.16718087]
# [INFO] loop count = 9910
# [INFO] update_w
#  [4.39968765 0.68326128 0.1671587 ]
# [INFO] loop count = 9911
# [INFO] update_w
#  [4.39976725 0.68330328 0.16713654]
# [INFO] loop count = 9912
# [INFO] update_w
#  [4.39984683 0.68334526 0.16711438]
# [INFO] loop count = 9913
# [INFO] update_w
#  [4.3999264  0.68338725 0.16709222]
# [INFO] loop count = 9914
# [INFO] update_w
#  [4.40000596 0.68342923 0.16707007]
# [INFO] loop count = 9915
# [INFO] update_w
#  [4.40008551 0.6834712  0.16704792]
# [INFO] loop count = 9916
# [INFO] update_w
#  [4.40016505 0.68351317 0.16702577]
# [INFO] loop count = 9917
# [INFO] update_w
#  [4.40024458 0.68355513 0.16700362]
# [INFO] loop count = 9918
# [INFO] update_w
#  [4.4003241  0.68359709 0.16698148]
# [INFO] loop count = 9919
# [INFO] update_w
#  [4.40040361 0.68363904 0.16695934]
# [INFO] loop count = 9920
# [INFO] update_w
#  [4.40048311 0.68368098 0.1669372 ]
# [INFO] loop count = 9921
# [INFO] update_w
#  [4.4005626  0.68372292 0.16691507]
# [INFO] loop count = 9922
# [INFO] update_w
#  [4.40064207 0.68376485 0.16689294]
# [INFO] loop count = 9923
# [INFO] update_w
#  [4.40072154 0.68380678 0.16687081]
# [INFO] loop count = 9924
# [INFO] update_w
#  [4.400801   0.68384871 0.16684869]
# [INFO] loop count = 9925
# [INFO] update_w
#  [4.40088044 0.68389062 0.16682656]
# [INFO] loop count = 9926
# [INFO] update_w
#  [4.40095988 0.68393253 0.16680445]
# [INFO] loop count = 9927
# [INFO] update_w
#  [4.4010393  0.68397444 0.16678233]
# [INFO] loop count = 9928
# [INFO] update_w
#  [4.40111872 0.68401634 0.16676022]
# [INFO] loop count = 9929
# [INFO] update_w
#  [4.40119812 0.68405824 0.16673811]
# [INFO] loop count = 9930
# [INFO] update_w
#  [4.40127751 0.68410013 0.166716  ]
# [INFO] loop count = 9931
# [INFO] update_w
#  [4.4013569  0.68414201 0.1666939 ]
# [INFO] loop count = 9932
# [INFO] update_w
#  [4.40143627 0.68418389 0.16667179]
# [INFO] loop count = 9933
# [INFO] update_w
#  [4.40151563 0.68422576 0.1666497 ]
# [INFO] loop count = 9934
# [INFO] update_w
#  [4.40159498 0.68426763 0.1666276 ]
# [INFO] loop count = 9935
# [INFO] update_w
#  [4.40167432 0.68430949 0.16660551]
# [INFO] loop count = 9936
# [INFO] update_w
#  [4.40175365 0.68435135 0.16658342]
# [INFO] loop count = 9937
# [INFO] update_w
#  [4.40183297 0.6843932  0.16656133]
# [INFO] loop count = 9938
# [INFO] update_w
#  [4.40191228 0.68443504 0.16653925]
# [INFO] loop count = 9939
# [INFO] update_w
#  [4.40199158 0.68447688 0.16651717]
# [INFO] loop count = 9940
# [INFO] update_w
#  [4.40207086 0.68451872 0.16649509]
# [INFO] loop count = 9941
# [INFO] update_w
#  [4.40215014 0.68456054 0.16647301]
# [INFO] loop count = 9942
# [INFO] update_w
#  [4.40222941 0.68460237 0.16645094]
# [INFO] loop count = 9943
# [INFO] update_w
#  [4.40230866 0.68464418 0.16642887]
# [INFO] loop count = 9944
# [INFO] update_w
#  [4.40238791 0.684686   0.16640681]
# [INFO] loop count = 9945
# [INFO] update_w
#  [4.40246714 0.6847278  0.16638474]
# [INFO] loop count = 9946
# [INFO] update_w
#  [4.40254637 0.6847696  0.16636268]
# [INFO] loop count = 9947
# [INFO] update_w
#  [4.40262558 0.6848114  0.16634063]
# [INFO] loop count = 9948
# [INFO] update_w
#  [4.40270479 0.68485319 0.16631857]
# [INFO] loop count = 9949
# [INFO] update_w
#  [4.40278398 0.68489497 0.16629652]
# [INFO] loop count = 9950
# [INFO] update_w
#  [4.40286316 0.68493675 0.16627447]
# [INFO] loop count = 9951
# [INFO] update_w
#  [4.40294233 0.68497852 0.16625243]
# [INFO] loop count = 9952
# [INFO] update_w
#  [4.4030215  0.68502029 0.16623038]
# [INFO] loop count = 9953
# [INFO] update_w
#  [4.40310065 0.68506205 0.16620834]
# [INFO] loop count = 9954
# [INFO] update_w
#  [4.40317979 0.68510381 0.16618631]
# [INFO] loop count = 9955
# [INFO] update_w
#  [4.40325892 0.68514556 0.16616427]
# [INFO] loop count = 9956
# [INFO] update_w
#  [4.40333804 0.6851873  0.16614224]
# [INFO] loop count = 9957
# [INFO] update_w
#  [4.40341715 0.68522904 0.16612021]
# [INFO] loop count = 9958
# [INFO] update_w
#  [4.40349625 0.68527078 0.16609819]
# [INFO] loop count = 9959
# [INFO] update_w
#  [4.40357533 0.68531251 0.16607617]
# [INFO] loop count = 9960
# [INFO] update_w
#  [4.40365441 0.68535423 0.16605415]
# [INFO] loop count = 9961
# [INFO] update_w
#  [4.40373348 0.68539595 0.16603213]
# [INFO] loop count = 9962
# [INFO] update_w
#  [4.40381254 0.68543766 0.16601012]
# [INFO] loop count = 9963
# [INFO] update_w
#  [4.40389158 0.68547937 0.16598811]
# [INFO] loop count = 9964
# [INFO] update_w
#  [4.40397062 0.68552107 0.1659661 ]
# [INFO] loop count = 9965
# [INFO] update_w
#  [4.40404964 0.68556276 0.16594409]
# [INFO] loop count = 9966
# [INFO] update_w
#  [4.40412866 0.68560445 0.16592209]
# [INFO] loop count = 9967
# [INFO] update_w
#  [4.40420766 0.68564614 0.16590009]
# [INFO] loop count = 9968
# [INFO] update_w
#  [4.40428666 0.68568782 0.1658781 ]
# [INFO] loop count = 9969
# [INFO] update_w
#  [4.40436564 0.68572949 0.1658561 ]
# [INFO] loop count = 9970
# [INFO] update_w
#  [4.40444461 0.68577116 0.16583411]
# [INFO] loop count = 9971
# [INFO] update_w
#  [4.40452357 0.68581282 0.16581213]
# [INFO] loop count = 9972
# [INFO] update_w
#  [4.40460253 0.68585448 0.16579014]
# [INFO] loop count = 9973
# [INFO] update_w
#  [4.40468147 0.68589613 0.16576816]
# [INFO] loop count = 9974
# [INFO] update_w
#  [4.4047604  0.68593777 0.16574618]
# [INFO] loop count = 9975
# [INFO] update_w
#  [4.40483932 0.68597942 0.16572421]
# [INFO] loop count = 9976
# [INFO] update_w
#  [4.40491823 0.68602105 0.16570223]
# [INFO] loop count = 9977
# [INFO] update_w
#  [4.40499713 0.68606268 0.16568026]
# [INFO] loop count = 9978
# [INFO] update_w
#  [4.40507602 0.6861043  0.1656583 ]
# [INFO] loop count = 9979
# [INFO] update_w
#  [4.4051549  0.68614592 0.16563633]
# [INFO] loop count = 9980
# [INFO] update_w
#  [4.40523377 0.68618753 0.16561437]
# [INFO] loop count = 9981
# [INFO] update_w
#  [4.40531262 0.68622914 0.16559241]
# [INFO] loop count = 9982
# [INFO] update_w
#  [4.40539147 0.68627074 0.16557046]
# [INFO] loop count = 9983
# [INFO] update_w
#  [4.40547031 0.68631234 0.1655485 ]
# [INFO] loop count = 9984
# [INFO] update_w
#  [4.40554913 0.68635393 0.16552656]
# [INFO] loop count = 9985
# [INFO] update_w
#  [4.40562795 0.68639551 0.16550461]
# [INFO] loop count = 9986
# [INFO] update_w
#  [4.40570676 0.68643709 0.16548267]
# [INFO] loop count = 9987
# [INFO] update_w
#  [4.40578555 0.68647867 0.16546072]
# [INFO] loop count = 9988
# [INFO] update_w
#  [4.40586434 0.68652024 0.16543879]
# [INFO] loop count = 9989
# [INFO] update_w
#  [4.40594311 0.6865618  0.16541685]
# [INFO] loop count = 9990
# [INFO] update_w
#  [4.40602187 0.68660336 0.16539492]
# [INFO] loop count = 9991
# [INFO] update_w
#  [4.40610063 0.68664491 0.16537299]
# [INFO] loop count = 9992
# [INFO] update_w
#  [4.40617937 0.68668646 0.16535106]
# [INFO] loop count = 9993
# [INFO] update_w
#  [4.4062581  0.686728   0.16532914]
# [INFO] loop count = 9994
# [INFO] update_w
#  [4.40633682 0.68676953 0.16530722]
# [INFO] loop count = 9995
# [INFO] update_w
#  [4.40641554 0.68681106 0.1652853 ]
# [INFO] loop count = 9996
# [INFO] update_w
#  [4.40649424 0.68685259 0.16526339]
# [INFO] loop count = 9997
# [INFO] update_w
#  [4.40657293 0.68689411 0.16524148]
# [INFO] loop count = 9998
# [INFO] update_w
#  [4.40665161 0.68693562 0.16521957]
# [INFO] loop count = 9999
# [INFO] update_w
#  [4.40673028 0.68697713 0.16519766]

# %%
# no_bias=False
slr = ScratchLinearRegression(num_iter=100001, lr=0.01, no_bias=False, verbose=False, verbose_filter=10000, q=0)
slr.fit(x, y)
# 予測実行
y_pred = slr.predict(x)
y_pred
# Out:
# [INFO] no_bias=False
# array([6., 7., 8.])

# %%
# no_bias=True
slr = ScratchLinearRegression(num_iter=200001, lr=0.01, no_bias=True, verbose=False, verbose_filter=10000, q=0)
slr.fit(x, y)
# 予測実行
y_pred = slr.predict(x)
y_pred
# Out:
# array([6., 7., 8.])

# %% [markdown]
# y=6,7,8のため、上記予測は正解と一致しているが、no_bias=Trueの場合は収束するまで多くの学習が必要になった。

# %% [markdown]
# ## 【問題4】平均二乗誤差
# 線形回帰の指標値として用いられる平均二乗誤差（mean square error, MSE）の関数を作成してください。
#
#
# 平均二乗誤差関数は回帰問題全般で使える関数のため、ScratchLinearRegressionクラスのメソッドではなく、別の関数として作成してください。雛形を用意してあります。
#
#
# 平均二乗誤差は以下の数式で表されます。
#
#
#
# $m$ : 入力されるデータの数
#
#
# $h_\theta()$ : 仮定関数
#
#
# $x^{(i)}$ : i番目のサンプルの特徴量ベクトル
#
#
# $y^{(i)}$ : i番目のサンプルの正解値
#
#
# なお、最急降下法のための目的関数（損失関数）としては、これを2で割ったものを使用します。（問題5, 9）
#
#
# **雛形**

# %%
def MSE(y_pred, y):
    """
    平均二乗誤差の計算

    Parameters
    ----------
    y_pred : 次の形のndarray, shape (n_samples,)
      推定した値
    y : 次の形のndarray, shape (n_samples,)
      正解値

    Returns
    ----------
    mse : numpy.float
      平均二乗誤差
    """

    assert y_pred.shape[0] == y.shape[0], "[ERROR] The shapes of y_pred and y are different. "

    mse = np.sum((y_pred - y) **2) / y_pred.shape[0]
    
    return mse

# %%
MSE(y_pred, y)
# Out:
# 1.0064008697956491e-24

# %% [markdown]
# ## 【問題5】目的関数
# 以下の数式で表される線形回帰の 目的関数（損失関数） を実装してください。そして、これをself.loss, self.val_lossに記録するようにしてください。
#
# 目的関数（損失関数） $J(\theta)$ は次の式です。
#
# $$
# \begin{equation*}
#   J_{(\theta)} =
#   \frac{1}{2m}\sum_{i=1}^{m}(h_\theta(x^{(i)})-y^{(i)})^2
# \end{equation*}
# $$
#
# $m$ : 入力されるデータの数
#
#
# $h_\theta()$ : 仮定関数
#
#
# $x^{(i)}$ : i番目のサンプルの特徴量ベクトル
#
#
# $y^{(i)}$ : i番目のサンプルの正解値

# %%
# no_bias=False
slr = ScratchLinearRegression(num_iter=20, lr=0.01, no_bias=False, verbose=False, verbose_filter=1, q=5)
slr.fit(x, y, x, y)
MSE(y_pred, y)
# Out:
# [INFO] no_bias=False
# 1.0064008697956491e-24

# %% [markdown]
# ## 3.検証
#
# ## 【問題6】学習と推定
# 機械学習スクラッチ入門のSprintで用意したHouse Pricesコンペティションのデータに対してスクラッチ実装の学習と推定を行なってください。
#
#
# scikit-learnによる実装と比べ、正しく動いているかを確認してください。

# %%
# # google colab環境用
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# # トレーニングデータ読み込み
# df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/dive_into_code/Sprint03/house-prices-advanced-regression-techniques/train.csv')
# df.head()

# %%
df = pd.read_csv('../data/house-prices-advanced-regression-techniques/train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# 相関の高い特徴量を抽出
df.corr()['SalePrice'].sort_values(ascending=False).head(5).index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea'], dtype='object')

# %%
# 今回は上記特徴量を使用
# X_columns = ['OverallQual', 'GrLivArea', 'GrLivArea', 'GarageCars', 'GarageArea']
X_columns = ['OverallQual', 'GrLivArea']
y_column = 'SalePrice'
X_df, y_df = df[X_columns].copy(), df[y_column].copy()

display(X_df.head())
display(y_df.head())
# Out:
#    OverallQual  GrLivArea
# 0            7       1710
# 1            6       1262
# 2            7       1786
# 3            7       1717
# 4            8       2198
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
# データ分割
X_train, X_test, y_train, y_test = [np.array(i.values) for i in train_test_split(X_df, y_df, test_size=0.3, random_state=0)]

# %%
# no_bias=False
slr2 = ScratchLinearRegression(num_iter=100001, lr=1e-7, no_bias=False, verbose=True, verbose_filter=100000)
slr2.fit(X_train, y_train, X_test, y_test)
print('loss :', slr2.loss)
print('val_loss :', slr2.val_loss)
# Out:
# [INFO] no_bias=False
# [INFO] loop count = 0
# [INFO] update_w
#  [ 2.01775278  2.11615357 31.90013082]
# [INFO] loop count = 100000
# [INFO] update_w
#  [ 15.70979618 434.8835925  116.05195724]
# loss : [1.87496760e+10 1.09648090e+10 6.68429218e+09 ... 1.43697842e+09
#  1.43697824e+09 1.43697806e+09]
# val_loss : [1.15390024e+10 7.25314339e+09 4.88262948e+09 ... 1.87333677e+09
#  1.87333652e+09 1.87333628e+09]

# %%
# 予測実行
y_pred2_1 = slr2.predict(X_test)
# 平均二乗誤差
MSE(y_pred2_1, y_test)
# Out:
# 3746672556.9267354

# %%
#線形回帰モデル
model = LinearRegression()
#学習はfit
model.fit(X_train, y_train)
print(model)
# 予測
y_pred2_2 = model.predict(X_test)
# 平均二乗誤差
print('MSE : ', MSE(y_pred2_2, y_test))
# 切片・回帰係数を表示
print('回帰係数 : \n{}'.format(pd.Series(model.coef_.reshape(len(model.coef_)), index=X_df.columns)))
print('切片 : {:.3f}'.format(model.intercept_))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# MSE :  2102735397.1381295
# 回帰係数 :
# OverallQual    31506.715061
# GrLivArea         61.368579
# dtype: float64
# 切片 : -104362.612

# %%
# MSE(平均二乗誤差)　※確認用として、sklearnで表示
mse = metrics.mean_squared_error(y_test, y_pred2_2)
print('MSE(平均二乗誤差)(test) : {:.3f}'.format(mse))
# Out:
# MSE(平均二乗誤差)(test) : 2102735397.138

# %% [markdown]
# ## 【問題7】学習曲線のプロット
# 学習曲線を表示する関数を作成し、実行してください。グラフを見て損失が適切に下がっているかどうか確認してください。
#
#
# 線形回帰クラスの雛形ではself.loss, self.val_lossに損失を記録しておくようになっているため、入力にはこれを利用してください。
#
#
# プロット例

# %%
# no_bias=False
slr3 = ScratchLinearRegression(num_iter=10001, lr=1e-9, no_bias=False, verbose=True, verbose_filter=1000)
slr3.fit(X_train, y_train, X_test, y_test)
print('loss :', slr3.loss)
print('val_loss :', slr3.val_loss)
# Out:
# [INFO] no_bias=False
# [INFO] loop count = 0
# [INFO] update_w
#  [2.00017753 2.00116154 2.29900131]
# [INFO] loop count = 1000
# [INFO] update_w
#  [  2.06446478   2.44387162 109.00475139]
# [INFO] loop count = 2000
# [INFO] update_w
#  [  2.07063699   2.51768048 117.02447029]
# [INFO] loop count = 3000
# [INFO] update_w
#  [  2.07244134   2.56376306 117.62707006]
# [INFO] loop count = 4000
# [INFO] update_w
#  [  2.07391739   2.60776167 117.67220839]
# [INFO] loop count = 5000
# [INFO] update_w
#  [  2.07536875   2.65160354 117.67544862]
# [INFO] loop count = 6000
# [INFO] update_w
#  [  2.07681824   2.69543351 117.67553984]
# [INFO] loop count = 7000
# [INFO] update_w
#  [  2.07826757   2.73926249 117.67539438]
# [INFO] loop count = 8000
# [INFO] update_w
#  [  2.07971687   2.78309128 117.67523113]
# [INFO] loop count = 9000
# [INFO] update_w
#  [  2.08116616   2.82691995 117.67506655]
# [INFO] loop count = 10000
# [INFO] update_w
#  [  2.08261542   2.87074849 117.67490187]
# loss : [1.87496760e+10 1.86603884e+10 1.85715618e+10 ... 1.45567989e+09
#  1.45567988e+09 1.45567988e+09]
# val_loss : [1.92105565e+10 1.91221496e+10 1.90341966e+10 ... 1.89827916e+09
#  1.89827916e+09 1.89827916e+09]

# %%
# no_bias=True
slr3_no = ScratchLinearRegression(num_iter=10001, lr=1e-9, no_bias=True, verbose=True, verbose_filter=1000)
slr3_no.fit(X_train, y_train, X_test, y_test)
print('loss :', slr3_no.loss)
print('val_loss :', slr3_no.val_loss)
# Out:
# [INFO] loop count = 0
# [INFO] update_w
#  [2.00116155 2.29900435]
# [INFO] loop count = 1000
# [INFO] update_w
#  [  2.4438766  109.00587071]
# [INFO] loop count = 2000
# [INFO] update_w
#  [  2.51768661 117.02568151]
# [INFO] loop count = 3000
# [INFO] update_w
#  [  2.56377003 117.62828951]
# [INFO] loop count = 4000
# [INFO] update_w
#  [  2.60776945 117.67342929]
# [INFO] loop count = 5000
# [INFO] update_w
#  [  2.65161213 117.67667041]
# [INFO] loop count = 6000
# [INFO] update_w
#  [  2.69544292 117.67676248]
# [INFO] loop count = 7000
# [INFO] update_w
#  [  2.7392727  117.67661788]
# [INFO] loop count = 8000
# [INFO] update_w
#  [  2.78310231 117.67645548]
# [INFO] loop count = 9000
# [INFO] update_w
#  [  2.82693179 117.67629175]
# [INFO] loop count = 10000
# [INFO] update_w
#  [  2.87076115 117.67612792]
# loss : [1.87500311e+10 1.86607417e+10 1.85719133e+10 ... 1.45568290e+09
#  1.45568290e+09 1.45568290e+09]
# val_loss : [1.92109121e+10 1.91225034e+10 1.90345487e+10 ... 1.89828594e+09
#  1.89828594e+09 1.89828593e+09]

# %%
import gc
def loss_plot(loss, val_loss, no_bias_loss=None, no_bias_val_loss=None, no_bias=True):
    
    if not no_bias:
        fig = plt.figure(figsize=(7, 5))
    else:
        fig = plt.figure(figsize=(14, 5))
    ax1 = fig.add_subplot(111)
    ax2 = fig.add_subplot(122)

    x1, x2 = list(range(1,len(loss)+1)), list(range(1, len(val_loss)+1))

    ax1.plot(x1, loss, label='train')
    ax1.plot(x2, val_loss, label='test')
    ax1.set_title('Learning curve - no_bias=False')
    ax1.grid(True)
    ax1.legend(loc='best')

    if no_bias:
        # ax2 = fig2.add_subplot(122)
        ax2.plot(x1, no_bias_loss, label='train')
        ax2.plot(x2, no_bias_val_loss, label='test')
        ax2.set_title('Learning curve - no_bias=True')
        ax2.grid(True)
        ax2.legend(loc='best')
    plt.show()
    del fig, ax1, ax2

# %%
def loss_plot(loss, val_loss, no_bias_loss=None, no_bias_val_loss=None):
    
    fig = plt.figure(figsize=(14, 5))
    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)

    x1, x2 = list(range(1,len(loss)+1)), list(range(1, len(val_loss)+1))

    ax1.plot(x1, loss, label='train')
    ax1.plot(x2, val_loss, label='test')
    ax1.set_title('Learning curve - no_bias=False')
    ax1.grid(True)
    ax1.legend(loc='best')

    ax2.plot(x1, no_bias_loss, label='train')
    ax2.plot(x2, no_bias_val_loss, label='test')
    ax2.set_title('Learning curve - no_bias=True')
    ax2.grid(True)
    ax2.legend(loc='best')

    plt.show()
    del fig, ax1, ax2

# %%
loss_plot(slr3.loss, slr3.val_loss, slr3_no.loss, slr3_no.val_loss)

# %% [markdown]
# ## 【問題8】（アドバンス課題）バイアス項の除去
# バイアス項 $\theta_0$ を抜くと学習がどう変化するか検証してください。また、線形回帰モデルにおけるバイアス項の役割の考察・調査を行ってください。

# %% [markdown]
# ### 標準化して実験

# %%
# 説明変数を標準化
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)
X_train_std
# Out:
# array([[ 0.67840248,  0.98899634],
#        [-0.05839596, -0.44659417],
#        [-0.79519441, -1.28321691],
#        ...,
#        [-0.05839596,  0.733952  ],
#        [ 0.67840248,  0.06735883],
#        [ 0.67840248,  0.61222629]])

# %%
# no_bias=False
slr4 = ScratchLinearRegression(num_iter=10001, lr=1e-3, no_bias=False, verbose=True, verbose_filter=10000)
slr4.fit(X_train_std, y_train, X_test_std, y_test)
print('loss :', slr4.loss)
print('val_loss :', slr4.val_loss)
# Out:
# [INFO] no_bias=False
# [INFO] loop count = 0
# [INFO] update_w
#  [182.58422896  63.23945485  58.63998347]
# [INFO] loop count = 10000
# [INFO] update_w
#  [180578.07952656  42677.72505099  31845.65287875]
# loss : [1.93549742e+10 1.93154270e+10 1.92759669e+10 ... 8.40920990e+08
#  8.40920988e+08 8.40920985e+08]
# val_loss : [1.98613209e+10 1.98209080e+10 1.97805851e+10 ... 1.05192399e+09
#  1.05192375e+09 1.05192352e+09]

# %%
# no_bias=True
slr4_no = ScratchLinearRegression(num_iter=10001, lr=1e-3, no_bias=True, verbose=True, verbose_filter=10000)
slr4_no.fit(X_train_std, y_train, X_test_std, y_test)
print('loss :', slr4_no.loss)
print('val_loss :', slr4_no.val_loss)
# Out:
# [INFO] loop count = 0
# [INFO] update_w
#  [63.23945485 58.63998347]
# [INFO] loop count = 10000
# [INFO] update_w
#  [42677.72505099 31845.65287875]
# loss : [1.93553354e+10 1.93483825e+10 1.93414516e+10 ... 1.71466140e+10
#  1.71466140e+10 1.71466140e+10]
# val_loss : [1.98944802e+10 1.98867976e+10 1.98791395e+10 ... 1.74267769e+10
#  1.74267761e+10 1.74267753e+10]

# %%
loss_plot(slr4.loss, slr4.val_loss, slr4_no.loss, slr4_no.val_loss)

# %%
# サンプルデータ
def f1(x):
    y = 0.3 * x + 50
    return y

x0 = np.arange(1, 101, 0.5)
y0 = (np.random.randint(1,30,200) + f1(x0)) * x0/150 + 30
slr8 = ScratchLinearRegression(num_iter=200001, lr=1e-7, no_bias=False, verbose=True, verbose_filter=200000)
slr8.fit(x0[:, np.newaxis], y0)
slr8_no = ScratchLinearRegression(num_iter=200001, lr=1e-7, no_bias=True, verbose=True, verbose_filter=200000)
slr8_no.fit(x0[:,np.newaxis], y0)

def f1(x, model):
    if not model.no_bias:
        y = model.w[1:] * x + model.w[0]
    else:
        y = model.w * x
    return y

y1 = f1(x0, slr8)
y2 = f1(x0, slr8_no)
# Out:
# [INFO] no_bias=False
# [INFO] loop count = 0
# [INFO] update_w
#  [29.99999271  1.99951535]
# [INFO] loop count = 200000
# [INFO] update_w
#  [29.96396478  0.57878979]
# [INFO] loop count = 0
# [INFO] update_w
#  [1.9996676]
# [INFO] loop count = 200000
# [INFO] update_w
#  [1.02488483]

# %%
plt.scatter(x0, y0)
plt.plot(x0, y1, color='red')
plt.plot(x0, y2, color='orange')
plt.xlim(0,100)
plt.ylim(0,100)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 【問題9】（アドバンス課題）特徴量の多次元化
# 特徴量の二乗や三乗を入力に利用すると学習結果がどう変化するか検証してください。

# %% [markdown]
# ### 特徴量の二乗

# %% [markdown]
# ### 特徴量の三乗

# %% [markdown]
# ## 【問題10】（アドバンス課題）更新式の導出
# 最急降下法の更新式は以下でした。この式が導出される過程を説明してください。
#
# $$
# \begin{align}
#   \theta_j :&=
#   \theta_j - \alpha\frac{1}{m}\sum_{i=1}^{m}\{(h_\theta(x^{(i)}) - y^{(i)})*x_j^{(i)}\}
# \end{align}
# $$
#
#
# 以下の式から説明をはじめることができます。
#
# $$
# \begin{align}
#   \theta_j :&=
#   \theta_j - \alpha\frac{\partial}{\partial{\theta_j}}J_{(\theta)} \\
# \end{align}
# $$
#
# 目的関数（損失関数） $J(\theta)$ は次の式です。
#
# $$
# \begin{equation*}
#   J_{(\theta)} =
#   \frac{1}{2m}\sum_{i=1}^{m}(h_\theta(x^{(i)}) - y^{(i)})^2
# \end{equation*}
# $$

# %% [markdown]
# ### ■解答
#
# $$
# \begin{equation*}
#   J_{(\theta)} =
#   \frac{1}{2m}\sum_{i=1}^{m}(h_\theta(x^{(i)}) - y^{(i)})^2
# \end{equation*}
# $$
#
# 上記$J_{(\theta)}$を下記のように$\theta_j$で偏微分を行う。
#
# $$
# \begin{equation*}
#   \frac{\partial}{\partial{\theta_j}}J_{(\theta)}
# \end{equation*}
# $$
#
# <br>
# ここで、$h_\theta(x^{(i)}) - y^{(i)}$を下記のように置く。
#
# $$
#   \begin{align}
#   h_\theta(x^{(i)}) - y^{(i)}
#   &= u_{(\theta)}\\
#   \end{align}
# $$
#
# <br>
# すると、$J_{(\theta)}$は下記と置ける。
#
# $$
# \begin{align}
#   J_{(\theta)}
#   &= \frac{1}{2m}\sum_{i=1}^{m}(h_0(x^{(i)}) - y^{(i)})^2 \\
#   &= \frac{1}{2m}\sum_{i=1}^{m}u_{(\theta)}^2
# \end{align}
# $$
#
# <br>
# ここで、合成関数の微分のチェーンルールより、求める偏微分計算は下記となる。
# $$
# \begin{equation*}
#   \frac{\partial{J_{(\theta)}}}{\partial{\theta_j}}
#   = \frac{\partial{J_{(\theta)}}}{\partial{u_{(\theta)}}}
#   * \frac{\partial{u_{(\theta)}}}{\partial{\theta_j}}
# \end{equation*}
# $$
#
# <br>
# なお、今回$h_0(x^{(i)})$は下記として、$J_{(\theta_0, \theta_1, \theta_2)}$ で考える。
#
# $$
#   \begin{align}
#   h_\theta(x^{(i)})
#   &= \theta_0 + \theta_1x_1^{(i)} + \theta_2x_2^{(i)} \\
#   \end{align}
# $$
#
# <br>
# $\frac{\partial{J_{(\theta_0, \theta_1, \theta_2)}}}
#  {\partial{u_{(\theta_0, \theta_1, \theta_2)}}}$ は下記と計算できる。
#
# $$
# \begin{align}
#   \frac{\partial{J_{(\theta_0, \theta_1, \theta_2)}}}
#   　　　{\partial{u_{(\theta_0, \theta_1, \theta_2)}}}
#   &= \frac{\partial}{\partial{u_{(\theta_0, \theta_1, \theta_2)}}}
#      \frac{1}{2m}\sum_{i=1}^{m}u_{(\theta_0, \theta_1, \theta_2)}^2 \\
#   &= \frac{1}{m}\sum_{i=1}^{m}u_{(\theta_0, \theta_1, \theta_2)}
# \end{align}
# $$

# %% [markdown]
# ■$j=0$のとき
# $$
# \begin{align}
#   \frac{\partial{u_{(\theta_0, \theta_1, \theta_2)}}}{\partial{\theta_0}}
#   &= \frac{\partial}{\partial{\theta_0}}
#      \theta_0 + \theta_1x_1^{(i)} + \theta_2x_2^{(i)} - y^{(i)} \\
#   &= 1
# \end{align}
# $$
# となり、
# $$
# \begin{align}
#   \frac{\partial{J_{(\theta_0, \theta_1, \theta_2)}}}{\partial{\theta_0}}
#   &= \frac{1}{m}\sum_{i=1}^{m}\{u_{(\theta_0, \theta_1, \theta_2)} * 1\} \\
#   &= \frac{1}{m}\sum_{i=1}^{m}\{\theta_0 + \theta_1x_1^{(i)} + \theta_2x_2^{(i)} - y^{(i)}\}
# \end{align}
# $$
# となる。

# %% [markdown]
# ■$j=1$のとき
# $$
# \begin{align}
#   \frac{\partial{u_{(\theta_0, \theta_1, \theta_2)}}}{\partial{\theta_1}}
#   &= \frac{\partial}{\partial{\theta_1}}
#      \theta_0 + \theta_1x_1^{(i)} + \theta_2x_2^{(i)} - y^{(i)} \\
#   &= x_1^{(i)}
# \end{align}
# $$
# となり、
# $$
# \begin{align}
#   \frac{\partial{J_{(\theta_0, \theta_1, \theta_2)}}}{\partial{\theta_1}}
#   &= \frac{1}{m}\sum_{i=1}^{m}\{u_{(\theta_0, \theta_1, \theta_2)} * x_1^{(i)}\} \\
#   &= \frac{1}{m}\sum_{i=1}^{m}\{(\theta_0 + \theta_1x_1^{(i)} + \theta_2x_2^{(i)} - y^{(i)})*x_1^{(i)}\}
# \end{align}
# $$
# となる。

# %% [markdown]
# ■$j=2$のとき
# $$
# \begin{align}
#   \frac{\partial{u_{(\theta_0, \theta_1, \theta_2)}}}{\partial{\theta_2}}
#   &= \frac{\partial}{\partial{\theta_2}}
#      \theta_0 + \theta_1x_1^{(i)} + \theta_2x_2^{(i)} - y^{(i)} \\
#   &= x_2^{(i)}\
# \end{align}
# $$
# となり、
# $$
# \begin{align}
#   \frac{\partial{J_{(\theta_0, \theta_1, \theta_2)}}}{\partial{\theta_2}}
#   &= \frac{1}{m}\sum_{i=1}^{m}\{u_{(\theta_0, \theta_1, \theta_2)} * x_2^{(i)}\} \\
#   &= \frac{1}{m}\sum_{i=1}^{m}\{(\theta_0 + \theta_1x_1^{(i)} + \theta_2x_2^{(i)} - y^{(i)})*x_2^{(i)}\}
# \end{align}
# $$
# となる。

# %% [markdown]
# よって、$h_\theta(x^{(i)}) - y^{(i)} = u_\theta$とおいていたため、また$x_0=1$のため下記となる。
#
# $$
# \begin{align}
#   \frac{\partial{J_{(\theta_0, \theta_1, \theta_2)}}}{\partial{\theta_j}}
#   &= \frac{1}{m}\sum_{i=1}^{m}\{u_{(\theta_0, \theta_1, \theta_2)} * x_j^{(i)}\} \\
#   &= \frac{1}{m}\sum_{i=1}^{m}\{(h_\theta(x^{(i)}) - y^{(i)})*x_j^{(i)}\}
# \end{align}
# $$
#
# なお、上記は$j>2$においても同様の計算となるため、下記となる。
# $$
# \begin{align}
#   \frac{\partial{J_{\theta}}}{\partial{\theta_j}}
# &= \frac{1}{m}\sum_{i=1}^{m}\{(h_\theta(x^{(i)}) - y^{(i)})*x_j^{(i)}\}
# \end{align}
# $$
#
# 以上より、パラメータ$\theta$の更新式は
# $$
# \begin{align}
#   \theta_j :&=
#   \theta_j - \alpha\frac{\partial}{\partial{\theta_j}}J_{(\theta)} \\
#   &= \theta_j - \alpha\frac{1}{m}\sum_{i=1}^{m}\{(h_\theta(x^{(i)}) - y^{(i)})*x_j^{(i)}\}
# \end{align}
# $$
# となる。

# %% [markdown]
# ## 【問題11】（アドバンス課題）局所最適解の問題
# 最急降下法には一般的に局所最適解の問題があります。しかし、線形回帰では学習を続ければ必ず最適解を求めることができます。それはなぜか数式やグラフを用いて説明してください。

# %% [markdown]
# ### ■解答
# 目的関数（損失関数） $J(\theta)$ は次の式で表すことができ、2次関数となる。
#
# $$
# \begin{equation*}
#   J_{(\theta)} =
#   \frac{1}{2m}\sum_{i=1}^{m}(h_\theta(x^{(i)}) - y^{(i)})^2
# \end{equation*}
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import Axes3D, proj3d

xs = np.array([2.8, 2.9, 3.0, 3.1, 3.2, 3.2, 3.2, 3.3, 3.4])
ys = np.array([30, 26, 33, 31, 33, 35, 37, 36, 33])

# 近似関数 a1 x^4 + a2 x^2
def f1(a1, a2):
    return a1 * xs**4 + a2 * xs ** 2

# 近似関数 sin(a1) x^4 + a2 x^2
def f2(a1, a2):
    return np.sin(a1) * xs**4 + a2 * xs ** 2

# 2乗誤差関数
def loss(a1, a2, f):
    return ((ys - f(a1, a2)) ** 2).sum()

# 各点での関数 loss の値を計算する。
A1, A2 = np.mgrid[-10:11, -10:11]
L1 = np.array([loss(a1, a2, f1) for a1, a2 in zip(A1.ravel(), A2.ravel())])
L2 = np.array([loss(a1, a2, f2) for a1, a2 in zip(A1.ravel(), A2.ravel())])
L1, L2 = L1.reshape(A1.shape), L2.reshape(A1.shape)

fig = plt.figure(figsize=(16, 8))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')
# 各軸のラベルを設定する。
ax1.set_xlabel('$X_1$', fontsize=15)
ax1.set_ylabel('$X_2$', fontsize=15)
ax1.set_zlabel('$loss$', fontsize=15)
ax2.set_xlabel('$X_1$', fontsize=15)
ax2.set_ylabel('$X_2$', fontsize=15)
ax2.set_zlabel('$loss$', fontsize=15)

# グラフを作成する。
ax1.plot_surface(A1, A2, L1, alpha=0.4, antialiased=False)
ax1.view_init(elev=50, azim=120)
ax2.plot_surface(A1, A2, L2, alpha=0.4, antialiased=False)
ax2.view_init(elev=50, azim=120)
